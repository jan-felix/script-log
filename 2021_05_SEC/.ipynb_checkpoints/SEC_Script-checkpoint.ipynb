# %% [markdown]
# # Project Idea:
# * Get SEC data
# * Create standardized balance sheets for a single company over time
# * Do a simple DCF Analysis
# * Turn it into modular functions
# * Maybe create a dashboard(?)
#
# Links:
# https://www.sec.gov/dera/data/financial-statement-data-sets.html
# https://www.sec.gov/dera/data/financial-statement-and-notes-data-set.html

# %%
import time
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from bs4 import BeautifulSoup
import requests
import os
import re
import zipfile
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import pandas_datareader as pdr
from itertools import chain
os.environ["ALPHAVANTAGE_API_KEY"] = pd.read_csv("ALPHAVANTAGE_API_KEY.txt").columns[0]

# %%
ticker_cik = pd.read_table("https://www.sec.gov/include/ticker.txt", names = ["Ticker","CIK"])
ticker_cik.to_csv("Ticker_to_CIK_Mapping.csv")#Ticker to SIC Code
sic_code_to_name = pd.read_html("https://www.sec.gov/info/edgar/siccodes.htm")[0] #For Sectors
sic_code_to_name.to_csv("sic_code_to_name.csv")

# %%
#Unzip all files in the database and turn num files into parquet data 
database = os.listdir("Database")
for file in database: 
    if "zip" in file: 
        with zipfile.ZipFile("Database/"+file,"r") as zip_ref:
            zip_ref.extractall("Database/"+file.replace("zip",""))
        os.remove("Database/"+file)
    if "num.parquet" not in os.listdir("Database/"+file):
        dtypes = {"fy":str,
                  "fye":str,
                  "period":str,
                  "ddate":str,
                  "sic":str,
                 "cik":str}
        num = pd.read_csv("Database/"+file+"/num.txt", sep="\t", dtype = dtypes)
        pq.write_table(pa.Table.from_pandas(num), "Database/"+file+"/num.parquet")
        del num

# %%
#Load data to RAM
t = time.process_time()
numdict = {}
subdict = {}
dtypes = {"fy":str,
          "fye":str,
          "period":str,
          "ddate":str,
          "sic":str,
         "cik":str}
for file in database: 
    numdict[file] = pq.read_table("Database/"+file+"/num.parquet").to_pandas()
    subdict[file] = pd.read_csv("Database/"+file+"/sub.txt", sep="\t", dtype = dtypes)
time.process_time()-t
# Out:
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 80.28125

# %% [markdown]
# ## Getting the Meta-data

# %%
# Variables we can parse out
name =  "APPLE INC"#E.g."MICROSOFT CORP"

# %%
#Downloading the data 
dtypes = {"fy":str,
          "fye":str,
          "period":str,
          "ddate":str}
file = "2021q1"
num = numdict[file]
sub = subdict[file]

# %%
symbol = ticker_cik[ticker_cik["CIK"]==sub[sub["name"]==name]["cik"].iloc[0]]["Ticker"].iloc[0] #Getting a Ticker

# %% [markdown]
# ## Getting the Data

# %% [markdown]
# ##### Short excursion: Calculating the Alpha of the stock
# ###### 1. Using Fama-French 3 Factor Model

# %%
#Getting stock prices and factors 
start = "2007-01-01"
end = datetime.now()

share_price_ts = pdr.DataReader(symbol, "av-weekly-adjusted", start=start,end=end)["adjusted close"]

ff_factors = pd.read_csv("Factor Data/Research_Data_Factors_weekly.csv",skiprows=4, index_col=0).dropna()
ff_factors.index = pd.DatetimeIndex(ff_factors.index)
ff_factors = ff_factors.resample("W").last()

share_price_ts.index = pd.DatetimeIndex(share_price_ts.index)
share_price_ts = share_price_ts.resample("W").last().pct_change()
ff_df = pd.concat([share_price_ts,ff_factors], axis=1)
ff_df = ff_df.dropna()

# %%
X = ff_df[['Mkt-RF', 'SMB', 'HML',"RF"]]
X = sm.add_constant(X)

model = sm.OLS(endog = ff_df["adjusted close"], exog = X, missing = "drop")
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         adjusted close   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     128.7
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):           1.92e-83
# Time:                        12:59:00   Log-Likelihood:                 1476.6
# No. Observations:                 747   AIC:                            -2943.
# Df Residuals:                     742   BIC:                            -2920.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.498      0.135      -0.001       0.005
# Mkt-RF         0.0113      0.001     22.109      0.000       0.010       0.012
# SMB           -0.0003      0.001     -0.341      0.733      -0.002       0.002
# HML           -0.0054      0.001     -7.247      0.000      -0.007      -0.004
# RF             0.0726      0.047      1.558      0.120      -0.019       0.164
# ==============================================================================
# Omnibus:                       62.487   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.304
# Skew:                          -0.102   Prob(JB):                     1.25e-69
# Kurtosis:                       6.186   Cond. No.                         105.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
information_ratio_ff = ((results.params["const"]+1)**12-1)/(results.resid.std()*np.sqrt(52))
information_ratio_ff
# Out:
# 0.11086430836822345

# %%
start = "2007-01-01"
end = datetime.now()

share_price_ts = pdr.DataReader(symbol, "av-weekly-adjusted", start=start,end=end)["adjusted close"]
market_factor = pdr.DataReader("VTSAX", "av-weekly-adjusted", start=start,end=end)["adjusted close"]
risk_free = pdr.DataReader("SHY", "av-weekly-adjusted", start=start,end=end)["adjusted close"]

#Calculating Alpha
return_equity = share_price_ts.pct_change()
return_market = market_factor.pct_change()
return_risk_free = risk_free.pct_change()
capm_df = pd.concat([return_equity,return_market,return_risk_free], axis=1).dropna()
capm_df.columns = ["Equity Return", "Market Return", "Risk-Free Return"]
capm_df["Risk Premium"] = capm_df["Market Return"] - capm_df["Risk-Free Return"]
capm_df.index = pd.DatetimeIndex(capm_df.index)

X = capm_df[["Risk-Free Return", "Risk Premium"]]
X = sm.add_constant(X)

model = sm.OLS(endog = capm_df["Equity Return"], exog = X, missing = "drop")
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Equity Return   R-squared:                       0.364
# Model:                            OLS   Adj. R-squared:                  0.362
# Method:                 Least Squares   F-statistic:                     214.6
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):           1.98e-74
# Time:                        12:59:16   Log-Likelihood:                 1463.0
# No. Observations:                 753   AIC:                            -2920.
# Df Residuals:                     750   BIC:                            -2906.
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0043      0.001      3.293      0.001       0.002       0.007
# Risk-Free Return    -0.0928      0.867     -0.107      0.915      -1.794       1.609
# Risk Premium         0.9605      0.051     18.675      0.000       0.859       1.061
# ==============================================================================
# Omnibus:                       60.083   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              289.728
# Skew:                          -0.100   Prob(JB):                     1.22e-63
# Kurtosis:                       6.032   Cond. No.                         685.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
information_ratio_capm = ((results.params["const"]+1)**12-1)/(results.resid.std()*np.sqrt(52))
information_ratio_capm
# Out:
# 0.21349946731878344

# %% [markdown]
# ## Back to topic: Getting Company reports

# %%
#Selecting a company and showing reports for the quarter
entity_sub = sub[sub["name"]==name]
entity_sub[["form","fy","fp","fye","period","adsh","accepted"]]
# Out:
#       form    fy   fp   fye    period                  adsh  \
# 267    8-K   NaN  NaN  0930  20201231  0001193125-21-001982
# 2551  10-Q  2021   Q1  0930  20201231  0000320193-21-000010
# 3037   8-K   NaN  NaN  0930  20210131  0000320193-21-000009
# 5356   8-K   NaN  NaN  0930  20210131  0001193125-21-032394
# 9015   8-K   NaN  NaN  0930  20210228  0001193125-21-054710
#
#                    accepted
# 267   2021-01-05 16:32:00.0
# 2551  2021-01-27 18:03:00.0
# 3037  2021-01-27 16:31:00.0
# 5356  2021-02-08 16:31:00.0
# 9015  2021-02-24 16:31:00.0

# %%
#filtering relevant data
quaterly_report_adsh = entity_sub[entity_sub["form"]=="10-Q"]["adsh"].iloc[0]
quaterly_report_period = entity_sub[entity_sub["form"]=="10-Q"]["period"].iloc[0]
entity_num_quarterly = num[num["adsh"] == quaterly_report_adsh]
entity_num_quarterly_period = entity_num_quarterly[entity_num_quarterly["ddate"]==quaterly_report_period]
eps_t = entity_num_quarterly_period[entity_num_quarterly_period["tag"]=="EarningsPerShareBasic"]["value"].iloc[0]

# %%
#Show current EPS
eps_t
# Out:
# 1.7

# %% [markdown]
# ## Checking the process: Does this work for 2010 data as well...?

# %%
dtypes = {"fy":str,
          "fye":str,
          "period":str,
          "ddate":str}
file = "2020q4"
num = numdict[file]
sub = subdict[file]

# %%
entity_sub = sub[sub["name"]==name]
entity_sub[["form","fy","fp","fye","period","adsh"]]
# Out:
#       form    fy   fp   fye    period                  adsh
# 3645   8-K   NaN  NaN  0930  20201031  0000320193-20-000094
# 4361  10-K  2020   FY  0930  20200930  0000320193-20-000096

# %%
quaterly_report_adsh = entity_sub[entity_sub["form"]=="10-K"]["adsh"].iloc[0]
quaterly_report_period = entity_sub[entity_sub["form"]=="10-K"]["period"].iloc[0]
entity_num_quarterly = num[num["adsh"] == quaterly_report_adsh]
entity_num_quarterly_period = entity_num_quarterly[entity_num_quarterly["ddate"]==quaterly_report_period]

# %%
entity_num_quarterly_period.head()
# Out:
#                         adsh                                            tag  \
# 351925  0000320193-20-000096                                  NetIncomeLoss
# 351926  0000320193-20-000096                                  NetIncomeLoss
# 364236  0000320193-20-000096                   PropertyPlantAndEquipmentNet
# 369312  0000320193-20-000096                            PaymentsOfDividends
# 374224  0000320193-20-000096  ProceedsFromSaleAndMaturityOfOtherInvestments
#
#              version coreg     ddate  qtrs  uom         value footnote
# 351925  us-gaap/2020  None  20200930     4  USD  5.741100e+10     None
# 351926  us-gaap/2020  None  20200930     1  USD  1.267300e+10     None
# 364236  us-gaap/2020  None  20200930     0  USD  3.676600e+10     None
# 369312  us-gaap/2020  None  20200930     4  USD  1.408100e+10     None
# 374224  us-gaap/2020  None  20200930     4  USD  9.200000e+07     None

# %%
entity_num_quarterly_period[entity_num_quarterly_period["qtrs"]==0]
# Out:
#                          adsh  \
# 364236   0000320193-20-000096
# 385425   0000320193-20-000096
# 400109   0000320193-20-000096
# 414863   0000320193-20-000096
# 445958   0000320193-20-000096
# ...                       ...
# 2108786  0000320193-20-000096
# 2108789  0000320193-20-000096
# 2108790  0000320193-20-000096
# 2108791  0000320193-20-000096
# 2108794  0000320193-20-000096
#
#                                                        tag  \
# 364236                        PropertyPlantAndEquipmentNet
# 385425                   OtherAccruedLiabilitiesNoncurrent
# 400109   LongTermDebtMaturitiesRepaymentsOfPrincipalInY...
# 414863   UnrecordedUnconditionalPurchaseObligationBalan...
# 445958                                    NoncurrentAssets
# ...                                                    ...
# 2108786  LesseeOperatingLeaseLeaseNotYetCommencedPaymen...
# 2108789                  OperatingandFinanceLeaseLiability
# 2108790            OperatingandFinanceLeaseRightofUseAsset
# 2108791  OperatingandFinanceLeaseWeightedAverageDiscoun...
# 2108794               PerformanceObligationsinArrangements
#
#                       version coreg     ddate  qtrs         uom         value  \
# 364236           us-gaap/2020  None  20200930     0         USD  3.676600e+10
# 385425           us-gaap/2020  None  20200930     0         USD  2.632000e+10
# 400109           us-gaap/2020  None  20200930     0         USD  9.569000e+09
# 414863           us-gaap/2020  None  20200930     0         USD  3.476000e+09
# 445958           us-gaap/2020  None  20200930     0         USD  3.676600e+10
# ...                       ...   ...       ...   ...         ...           ...
# 2108786  0000320193-20-000096  None  20200930     0         USD  1.700000e+09
# 2108789  0000320193-20-000096  None  20200930     0         USD  9.842000e+09
# 2108790  0000320193-20-000096  None  20200930     0         USD  9.199000e+09
# 2108791  0000320193-20-000096  None  20200930     0        pure  2.000000e-02
# 2108794  0000320193-20-000096  None  20200930     0  obligation  3.000000e+00
#
#         footnote
# 364236      None
# 385425      None
# 400109      None
# 414863      None
# 445958      None
# ...          ...
# 2108786     None
# 2108789     None
# 2108790     None
# 2108791     None
# 2108794     None
#
# [127 rows x 9 columns]

# %% [markdown]
# ## It does!

# %% [markdown]
# ## Setting up a process to iterate through files

# %%
#loading database again without zips
database = os.listdir("Database")
eps_list = list()
date_list = list()
for file in database:
    dtypes = {"fy":str,
              "fye":str,
              "period":str,
              "ddate":str}
    num = numdict[file]
    sub = subdict[file]
    report_type = "10-Q"
    
    if name not in sub["name"].unique(): #If the firm we are looking for is not in the metadata for that quarter, we dont need to get into numbers
        print(name+" not in "+file)
    else: 
        entity_sub = sub[sub["name"]==name]
        print("Reports for "+file)
        print(entity_sub[["form","fy","fp","fye","period","adsh"]])
        if "10-Q" not in entity_sub["form"].unique(): #If our firm did not release a 10-Q, we check if we find the 10-K (they do not release both in the quarter after their year end)
            print("No 10-Q in "+file+", using 10-K instead")
            report_type = "10-K"

        quaterly_report_adsh = entity_sub[entity_sub["form"]==report_type]["adsh"].iloc[0] #fetch report identifier "adsh"
        quaterly_report_period = entity_sub[entity_sub["form"]==report_type]["period"].iloc[0] #fetch report accounting period
        entity_num_quarterly = num[num["adsh"] == quaterly_report_adsh] #fetch report
        entity_num_quarterly_period = entity_num_quarterly[entity_num_quarterly["ddate"]==quaterly_report_period] #Only get the data for the current period
        eps_t = entity_num_quarterly_period[entity_num_quarterly_period["tag"]=="EarningsPerShareBasic"]["value"].iloc[0]

        date_list.append(quaterly_report_period)
        eps_list.append(eps_t)

        print("EPS in "+str(quaterly_report_period)+": "+str(eps_t))
# Out:
# APPLE INC not in 2009q1
# APPLE INC not in 2009q2
# Reports for 2009q3
#    form    fy  fp   fye    period                  adsh
# 5  10-Q  2009  Q3  0930  20090630  0001193125-09-153165
# EPS in 20090630: 1.38
# Reports for 2009q4
#     form    fy  fp   fye    period                  adsh
# 67  10-K  2009  FY  0930  20090930  0001193125-09-214859
# No 10-Q in 2009q4, using 10-K instead
# EPS in 20090930: 6.39
# Reports for 2010q1
#        form    fy  fp   fye    period                  adsh
# 482    10-Q  2010  Q1  0930  20091231  0001193125-10-012085
# 483  10-K/A  2009  FY  0930  20090930  0001193125-10-012091
# EPS in 20091231: 3.74
# Reports for 2010q2
#     form    fy  fp   fye    period                  adsh
# 16  10-Q  2010  Q2  0930  20100331  0001193125-10-088957
# EPS in 20100331: 7.12
# Reports for 2010q3
#     form    fy  fp   fye    period                  adsh
# 27  10-Q  2010  Q3  0930  20100630  0001193125-10-162840
# EPS in 20100630: 10.69
# Reports for 2010q4
#      form    fy  fp   fye    period                  adsh
# 167  10-K  2010  FY  0930  20100930  0001193125-10-238044
# No 10-Q in 2010q4, using 10-K instead
# EPS in 20100930: 4.71
# Reports for 2011q1
#       form    fy  fp   fye    period                  adsh
# 1454  10-Q  2011  Q1  0930  20101231  0001193125-11-010144
# EPS in 20101231: 6.53
# Reports for 2011q2
#     form    fy  fp   fye    period                  adsh
# 86  10-Q  2011  Q2  0930  20110331  0001193125-11-104388
# EPS in 20110331: 6.49
# Reports for 2011q3
#     form    fy  fp   fye    period                  adsh
# 67  10-Q  2011  Q3  0930  20110630  0001193125-11-192493
# EPS in 20110630: 20.91
# Reports for 2011q4
#      form    fy  fp   fye    period                  adsh
# 521  10-K  2011  FY  0930  20110930  0001193125-11-282113
# No 10-Q in 2011q4, using 10-K instead
# EPS in 20110930: 7.13
# Reports for 2012q1
#       form    fy  fp   fye    period                  adsh
# 6918  10-Q  2012  Q1  0930  20111231  0001193125-12-023398
# EPS in 20111231: 14.03
# Reports for 2012q2
#       form    fy  fp   fye    period                  adsh
# 1403  10-Q  2012  Q2  0930  20120331  0001193125-12-182321
# EPS in 20120331: 12.45
# Reports for 2012q3
#      form    fy  fp   fye    period                  adsh
# 670  10-Q  2012  Q3  0930  20120630  0001193125-12-314552
# EPS in 20120630: 9.42
# Reports for 2012q4
#       form    fy  fp   fye    period                  adsh
# 1326  10-K  2012  FY  0930  20120930  0001193125-12-444068
# No 10-Q in 2012q4, using 10-K instead
# EPS in 20120930: 44.64
# Reports for 2013q1
#      form    fy  fp   fye    period                  adsh
# 563  10-Q  2013  Q1  0930  20121231  0001193125-13-022339
# EPS in 20121231: 13.93
# Reports for 2013q2
#       form    fy  fp   fye    period                  adsh
# 1740  10-Q  2013  Q2  0930  20130331  0001193125-13-168288
# 1761   8-K  2012  FY  0930  20120930  0001193125-13-170623
# EPS in 20130331: 24.09
# Reports for 2013q3
#      form    fy  fp   fye    period                  adsh
# 708  10-Q  2013  Q3  0930  20130630  0001193125-13-300670
# EPS in 20130630: 31.67
# Reports for 2013q4
#       form    fy  fp   fye    period                  adsh
# 1158  10-K  2013  FY  0930  20130930  0001193125-13-416534
# No 10-Q in 2013q4, using 10-K instead
# EPS in 20130930: 8.31
# Reports for 2014q1
#      form    fy  fp   fye    period                  adsh
# 661  10-Q  2014  Q1  0930  20131231  0001193125-14-024487
# EPS in 20131231: 14.59
# Reports for 2014q2
#       form    fy  fp   fye    period                  adsh
# 1281  10-Q  2014  Q2  0930  20140331  0001193125-14-157311
# EPS in 20140331: 11.69
# Reports for 2014q3
#      form    fy  fp   fye    period                  adsh
# 583  10-Q  2014  Q3  0930  20140630  0001193125-14-277160
# EPS in 20140630: 5.06
# Reports for 2014q4
#      form    fy  fp   fye    period                  adsh
# 775  10-K  2014  FY  0930  20140930  0001193125-14-383437
# No 10-Q in 2014q4, using 10-K instead
# EPS in 20140930: 6.49
# Reports for 2015q1
#      form    fy  fp   fye    period                  adsh
# 565  10-Q  2015  Q1  0930  20141231  0001193125-15-023697
# 566   8-K  2014  FY  0930  20140930  0001193125-15-023732
# EPS in 20141231: 3.08
# Reports for 2015q2
#       form    fy  fp   fye    period                  adsh
# 1356  10-Q  2015  Q2  0930  20150331  0001193125-15-153166
# EPS in 20150331: 2.34
# Reports for 2015q3
#      form    fy  fp   fye    period                  adsh
# 515  10-Q  2015  Q3  0930  20150630  0001193125-15-259935
# EPS in 20150630: 1.86
# Reports for 2015q4
#      form    fy  fp   fye    period                  adsh
# 796  10-K  2015  FY  0930  20150930  0001193125-15-356351
# No 10-Q in 2015q4, using 10-K instead
# EPS in 20150930: 1.97
# Reports for 2016q1
#      form    fy  fp   fye    period                  adsh
# 481  10-Q  2016  Q1  0930  20151231  0001193125-16-439878
# EPS in 20151231: 3.3
# Reports for 2016q2
#       form    fy  fp   fye    period                  adsh
# 1154  10-Q  2016  Q2  0930  20160331  0001193125-16-559625
# EPS in 20160331: 1.91
# Reports for 2016q3
#      form    fy  fp   fye    period                  adsh
# 661  10-Q  2016  Q3  0930  20160630  0001628280-16-017809
# EPS in 20160630: 1.43
# Reports for 2016q4
#      form    fy  fp   fye    period                  adsh
# 650  10-K  2016  FY  0930  20160930  0001628280-16-020309
# No 10-Q in 2016q4, using 10-K instead
# EPS in 20160930: 1.68
# Reports for 2017q1
#      form    fy  fp   fye    period                  adsh
# 590  10-Q  2017  Q1  0930  20161231  0001628280-17-000717
# EPS in 20161231: 3.38
# Reports for 2017q2
#       form    fy  fp   fye    period                  adsh
# 2032  10-Q  2017  Q2  0930  20170331  0001628280-17-004790
# EPS in 20170331: 2.11
# Reports for 2017q3
#       form    fy  fp   fye    period                  adsh
# 1197  10-Q  2017  Q3  0930  20170630  0000320193-17-000009
# EPS in 20170630: 1.68
# Reports for 2017q4
#       form    fy  fp   fye    period                  adsh
# 1821  10-K  2017  FY  0930  20170930  0000320193-17-000070
# No 10-Q in 2017q4, using 10-K instead
# EPS in 20170930: 2.08
# Reports for 2018q1
#      form    fy  fp   fye    period                  adsh
# 610  10-Q  2018  Q1  0930  20171231  0000320193-18-000007
# EPS in 20171231: 3.92
# Reports for 2018q2
#       form    fy  fp   fye    period                  adsh
# 2029  10-Q  2018  Q2  0930  20180331  0000320193-18-000070
# EPS in 20180331: 2.75
# Reports for 2018q3
#       form    fy  fp   fye    period                  adsh
# 1101  10-Q  2018  Q3  0930  20180630  0000320193-18-000100
# EPS in 20180630: 2.36
# Reports for 2018q4
#       form    fy  fp   fye    period                  adsh
# 1828  10-K  2018  FY  0930  20180930  0000320193-18-000145
# No 10-Q in 2018q4, using 10-K instead
# EPS in 20180930: 2.94
# Reports for 2019q1
#      form    fy  fp   fye    period                  adsh
# 262  10-Q  2019  Q1  0930  20181231  0000320193-19-000010
# EPS in 20181231: 4.22
# Reports for 2019q2
#       form    fy  fp   fye    period                  adsh
# 1909  10-Q  2019  Q2  0930  20190331  0000320193-19-000066
# EPS in 20190331: 6.7
# Reports for 2019q3
#       form    fy   fp   fye    period                  adsh
# 1195  10-Q  2019   Q3  0930  20190630  0000320193-19-000076
# 8041   8-K   NaN  NaN  0930  20190831  0001193125-19-242975
# 8242   8-K   NaN  NaN  0930  20190831  0000320193-19-000093
# EPS in 20190630: 2.2
# Reports for 2019q4
#       form    fy   fp   fye    period                  adsh
# 2609   8-K   NaN  NaN  0930  20191031  0000320193-19-000117
# 3210  10-K  2019   FY  0930  20190930  0000320193-19-000119
# 9100   8-K   NaN  NaN  0930  20191031  0001193125-19-292676
# No 10-Q in 2019q4, using 10-K instead
# EPS in 20190930: 3.05
# Reports for 2020q1
#       form    fy   fp   fye    period                  adsh
# 1779   8-K   NaN  NaN  0930  20200131  0000320193-20-000008
# 1934  10-Q  2020   Q1  0930  20191231  0000320193-20-000010
# 4923   8-K   NaN  NaN  0930  20200229  0001193125-20-039203
# 7352   8-K   NaN  NaN  0930  20200229  0001193125-20-050884
# EPS in 20191231: 5.04
# Reports for 2020q2
#       form    fy   fp   fye    period                  adsh
# 4044   8-K   NaN  NaN  0930  20200430  0000320193-20-000050
# 4604  10-Q  2020   Q2  0930  20200331  0000320193-20-000052
# 8704   8-K   NaN  NaN  0930  20200430  0001193125-20-139112
# EPS in 20200331: 2.58
# Reports for 2020q3
#        form    fy   fp   fye    period                  adsh
# 3049    8-K   NaN  NaN  0930  20200731  0000320193-20-000060
# 3567   10-Q  2020   Q3  0930  20200630  0000320193-20-000062
# 7052    8-K   NaN  NaN  0930  20200731  0001193125-20-213158
# 10735   8-K   NaN  NaN  0930  20200731  0001193125-20-225672
# EPS in 20200630: 2.61
# Reports for 2020q4
#       form    fy   fp   fye    period                  adsh
# 3645   8-K   NaN  NaN  0930  20201031  0000320193-20-000094
# 4361  10-K  2020   FY  0930  20200930  0000320193-20-000096
# No 10-Q in 2020q4, using 10-K instead
# EPS in 20200930: 3.31
# Reports for 2021q1
#       form    fy   fp   fye    period                  adsh
# 267    8-K   NaN  NaN  0930  20201231  0001193125-21-001982
# 2551  10-Q  2021   Q1  0930  20201231  0000320193-21-000010
# 3037   8-K   NaN  NaN  0930  20210131  0000320193-21-000009
# 5356   8-K   NaN  NaN  0930  20210131  0001193125-21-032394
# 9015   8-K   NaN  NaN  0930  20210228  0001193125-21-054710
# EPS in 20201231: 1.7

# %%
#Construct EPS Data Frame
df = pd.DataFrame({"Date":date_list,"EPS":eps_list})
df.index = pd.DatetimeIndex(df["Date"])
df = df.drop("Date", axis=1)
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Yep, this seems to work as well. Let's make a process to get *all* the data, not just one variable

# %% [markdown]
# ###### Get all firms and all sector (SIC) codes

# %%
all_firms_list = list()
database = os.listdir("Database")
for file in database:
    dtypes = {"fy":str,
              "fye":str,
              "period":str,
              "ddate":str,
             "sic":str}
    sub = sub = subdict[file]
    sub["name_sic_cik"] = sub["name"]+"_"+sub["sic"].astype(str)+"_"+sub["cik"].astype(str)
    all_firms_list.append(sub["name_sic_cik"].unique())
all_firms_list = set(list(chain(*all_firms_list)))

firms_list = list()
for i in range(0,len(all_firms_list)):
    firms_dic = {"Firm":None,
                 "SIC":None,
                 "CIK":None}
    firms_dic["Firm"] = (list(all_firms_list)[i].split("_"))[0]
    firms_dic["SIC"] = (list(all_firms_list)[i].split("_"))[1]
    firms_dic["CIK"] = (list(all_firms_list)[i].split("_"))[2]
    firms_list.append(firms_dic)

# %%
firms_dict_df = pd.DataFrame.from_dict(firms_list)
firms_dict_df.head()
# Out:
#                                      Firm   SIC      CIK
# 0                   L3 TECHNOLOGIES, INC.  3663  1039101
# 1                            RUDDICK CORP  5411    85704
# 2                         STELLA BLU, INC  6794  1581220
# 3  VIRTUAL INTERACTIVE TECHNOLOGIES CORP.  1000  1536089
# 4               APPLIED BIOSCIENCES CORP.  2040  1607549

# %% [markdown]
# ###### Keep only firms that have a market ticker:

# %%
ticker_cik["CIK"] = ticker_cik["CIK"].astype(str)
firms_df = pd.merge(firms_dict_df,ticker_cik, left_on="CIK", right_on="CIK").drop_duplicates(["SIC","CIK","Ticker"])
sic_code_to_name["SIC Code"] = sic_code_to_name["SIC Code"].astype(str)
firms_df = pd.merge(firms_df,sic_code_to_name, left_on="SIC",right_on="SIC Code")
firms_df.head()
# Out:
#                                   Firm   SIC      CIK Ticker SIC Code  \
# 0                      STELLA BLU, INC  6794  1581220   xall     6794
# 1                           VRINGO INC  6794  1410428   xspa     6794
# 2        ALL MARKETING SOLUTIONS, INC.  6794  1464300   ptpf     6794
# 3  UNITED STATES BASKETBALL LEAGUE INC  6794   764630   usbl     6794
# 4                      DINEEQUITY, INC  6794    49754    din     6794
#
#                                  Office           Industry Title
# 0  Office of Real Estate & Construction  PATENT OWNERS & LESSORS
# 1  Office of Real Estate & Construction  PATENT OWNERS & LESSORS
# 2  Office of Real Estate & Construction  PATENT OWNERS & LESSORS
# 3  Office of Real Estate & Construction  PATENT OWNERS & LESSORS
# 4  Office of Real Estate & Construction  PATENT OWNERS & LESSORS

# %% [markdown]
# ###### FInd all firms in a specific industry

# %%
firms_df[firms_df["Industry Title"]=="PATENT OWNERS & LESSORS"].head()
# Out:
#                                   Firm   SIC      CIK Ticker SIC Code  \
# 0                      STELLA BLU, INC  6794  1581220   xall     6794
# 1                           VRINGO INC  6794  1410428   xspa     6794
# 2        ALL MARKETING SOLUTIONS, INC.  6794  1464300   ptpf     6794
# 3  UNITED STATES BASKETBALL LEAGUE INC  6794   764630   usbl     6794
# 4                      DINEEQUITY, INC  6794    49754    din     6794
#
#                                  Office           Industry Title
# 0  Office of Real Estate & Construction  PATENT OWNERS & LESSORS
# 1  Office of Real Estate & Construction  PATENT OWNERS & LESSORS
# 2  Office of Real Estate & Construction  PATENT OWNERS & LESSORS
# 3  Office of Real Estate & Construction  PATENT OWNERS & LESSORS
# 4  Office of Real Estate & Construction  PATENT OWNERS & LESSORS

# %% [markdown]
# ##### Run Process for a single firm

# %%
t = time.process_time()
start = "2007-01-01"
end = datetime.now()
market_factor = pdr.DataReader("VTSAX", "av-weekly-adjusted", start=start,end=end)["adjusted close"]
risk_free = pdr.DataReader("SHY", "av-weekly-adjusted", start=start,end=end)["adjusted close"]
return_market = market_factor.pct_change()
return_risk_free = risk_free.pct_change()
elapsed_time = time.process_time() - t
elapsed_time
# Out:
# 0.09375

# %%
t = time.process_time()
#loading database again without zips
database = os.listdir("Database")
report_list = list() #this will get all reports
date_list = list()
annual_report_list = list() #from this we can make a balance sheet file 
annual_report_date_list = list() #dates for balance sheet file
market_data_list = list() #market_data list for regressions etc. 
share_price_ts = []

CIK = "320193"
name = str(firms_df[firms_df["CIK"]==CIK]["Firm"].iloc[0])
print("IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII")
print("Starting with: "+name)
for file in database:
    dtypes = {"fy":str,
              "fye":str,
              "period":str,
              "ddate":str,
              "sic":str,
             "cik":str}

    sub = subdict[file]
    report_type = "10-Q"
    
    if CIK not in sub["cik"].unique(): #If the firm we are looking for is not in the metadata for that quarter, we dont need to get into numbers
        print(name+" not in "+file)
        continue 
   
    entity_sub = sub[sub["cik"]==CIK]
    print("Report that was published in: "+file)
    print(entity_sub[["form","fy","fp","fye","period","adsh","accepted"]])
    if "10-Q" not in entity_sub["form"].unique(): #If our firm did not release a 10-Q, we check if we find the 10-K (they do not release both in the quarter after their year end)
        print("No 10-Q in "+file+", fetching 10-K instead")
        report_type = "10-K"
        if "10-K" not in entity_sub["form"].unique(): #If our firm released neither 10-Q nor a 10-K 
            print("No 10-Q or 10-K for "+file+" skipping to next quarter")
            continue
    
    num = numdict[file]
    #Get the meta data
    quaterly_report_adsh = entity_sub[entity_sub["form"]==report_type]["adsh"].iloc[0] #fetch report identifier "adsh"
    quaterly_report_period = entity_sub[entity_sub["form"]==report_type]["period"].iloc[0] #fetch report accounting period
    
    #Get the market data
    first_filing_date = datetime.strptime(entity_sub[entity_sub["form"]==report_type]["accepted"].iloc[0].replace(".0",""), "%Y-%m-%d %H:%M:%S") #fetch report acceptance date
        
    print("Fetching Report that was published in :  "+str(quaterly_report_period))
    
    #For the first date for which we have accounting data, download all the data we need for the CAPM 
    if ((date_list==[]) and (type(first_filing_date)==datetime)): #only do this once
        #Get the symbol for stock market API
        #Setting up dictionary
        regression_stats_dict = {"filing_date":None,
                                "next_year_beta":None,
                                "next_year_beta_tstat":None,
                                "next_year_alpha":None,
                                "next_year_alpha_tstat":None,
                                "next_year_IR":None,
                                "next_year_market_return":None,
                                "next_year_equity_return":None,
                                "last_year_start_date":None,
                                "last_year_beta":None, 
                                "last_year_beta_tstat":None,
                                "last_year_alpha":None, 
                                "last_year_alpha_tstat":None,
                                "last_year_IR": None,
                                "last_year_market_return":None,
                                "last_year_equity_return":None,
                                "last_year_vola":None, 
                                "last_year_vola_explained_by_market":None}    
        
        
        #Getting stock prices and factors 
        start = first_filing_date-pd.Timedelta(52,"W")
        end = datetime.now()

        try:
            share_price_ts = pdr.DataReader(str(firms_df[firms_df["CIK"]==CIK]["Ticker"].iloc[0]), "av-weekly-adjusted", start=start,end=end)["adjusted close"]
        except ValueError:
            try:
                share_price_ts = pdr.DataReader(str(firms_df[firms_df["CIK"]==CIK]["Ticker"].iloc[1]), "av-weekly-adjusted", start=start,end=end)["adjusted close"]
            except ValueError:
                print('No Stock Prices available')
                #Get the accounting data 
                entity_num_quarterly = num[num["adsh"] == quaterly_report_adsh] #fetch report
                entity_num_quarterly_period = entity_num_quarterly[(entity_num_quarterly["ddate"]==quaterly_report_period)&
                                                                   entity_num_quarterly["qtrs"].isin([0,1])] #Only get the data for the last quarter
                date_list.append(quaterly_report_period)
                report_list.append(entity_num_quarterly_period)

                if report_type == "10-K":
                    annual_report_list.append(entity_num_quarterly[(entity_num_quarterly["ddate"]==quaterly_report_period)&
                                                                    entity_num_quarterly["qtrs"].isin([0,4])])#Get last year data
                    annual_report_date_list.append(quaterly_report_period)
                    print("Also saving this as 10-K report")
                print("################################################## Next Period#################################################")
                continue

        return_equity = share_price_ts.pct_change()
        capm_df = pd.concat([return_equity,return_market,return_risk_free], axis=1).dropna()
        capm_df.columns = ["Equity Return", "Market Return", "Risk-Free Return"]
        capm_df["Risk_Premium_Beta"] = capm_df["Market Return"] - capm_df["Risk-Free Return"]         
        capm_df.index = pd.DatetimeIndex(capm_df.index)
            
        
    #Next year Stock analysis:
    if type(first_filing_date) == datetime:
        #Setup and run regression
        period_start = first_filing_date
        period_end = first_filing_date+pd.Timedelta(52,"W")
        reg_df = capm_df.loc[period_start:period_end]
        X = reg_df[["Risk-Free Return", "Risk_Premium_Beta"]]
        X = sm.add_constant(X)
        model = sm.OLS(endog = reg_df["Equity Return"], exog = X, missing = "drop")
        results = model.fit()
        information_ratio_capm = ((results.params["const"]+1)**12-1)/(results.resid.std()*np.sqrt(52))
       
        #Printing relevant data
        print("Equity Market Stats for 1Y since Filing on: "+str(first_filing_date))
        print(results.params)
        print("With T-Values:")
        print(results.tvalues)
        print("Information Ratio last year: "+str(information_ratio_capm))
        
        #Saving Data
        regression_stats_dict["filing_date"] = first_filing_date
        regression_stats_dict["next_year_beta"] = results.params["Risk_Premium_Beta"]
        regression_stats_dict["next_year_beta_tstat"] = results.tvalues["Risk_Premium_Beta"]
        regression_stats_dict["next_year_alpha"] = results.params["const"]
        regression_stats_dict["next_year_alpha_tstat"] = results.tvalues["const"]
        regression_stats_dict["next_year_IR"] = information_ratio_capm
        regression_stats_dict["next_year_market_return"] = (reg_df["Market Return"]+1).iloc[-1]-1
        regression_stats_dict["next_year_equity_return"] = (reg_df["Equity Return"]+1).iloc[-1]-1
        
        
        #Make dataframe and store it to list here already if we have not enough data for historic analysis
        if len(capm_df.loc[first_filing_date-pd.Timedelta(52,"w"):first_filing_date])< 26:
            market_data_df = pd.DataFrame.from_dict(regression_stats_dict,orient='index')
            market_data_df.columns = [quaterly_report_period]
            market_data_list.append(market_data_df)
            
    #Historic Stock Return Analysis if we have 26 weeks of data (1/2 year)
    if len(capm_df.loc[first_filing_date-pd.Timedelta(52,"w"):first_filing_date])>= 26:
        #Setup and run regression
        period_start = first_filing_date-pd.Timedelta(52,"w")
        period_end = first_filing_date
        reg_df = capm_df.loc[period_start:period_end]
        X = reg_df[["Risk-Free Return", "Risk_Premium_Beta"]]
        X = sm.add_constant(X)
        model = sm.OLS(endog = reg_df["Equity Return"], exog = X, missing = "drop")
        results = model.fit()
        information_ratio_capm = ((results.params["const"]+1)**12-1)/(results.resid.std()*np.sqrt(52))
        
        #Printing relevant data
        print("1Y Historic Equity Market Stats (filing between): "+str(period_start)+" and "+str(period_end))
        print(results.params)
        print("With T-Values:")
        print(results.tvalues)
        print("Information Ratio next year:"+str(information_ratio_capm))
        
        #saving relevant data
        regression_stats_dict["last_year_start_date"] = reg_df.first_valid_index()
        regression_stats_dict["last_year_beta"] = results.params["Risk_Premium_Beta"]
        regression_stats_dict["last_year_beta_tstat"]= results.tvalues["Risk_Premium_Beta"]
        regression_stats_dict["last_year_alpha"]=results.params["const"]
        regression_stats_dict["last_year_alpha_tstat"]=results.tvalues["const"]
        regression_stats_dict["last_year_IR"] = information_ratio_capm
        regression_stats_dict["last_year_market_return"]=(reg_df["Market Return"]+1).iloc[-1]-1
        regression_stats_dict["last_year_equity_return"]=(reg_df["Equity Return"]+1).iloc[-1]-1
        regression_stats_dict["last_year_vola"]= reg_df["Equity Return"].std()*np.sqrt(len(reg_df))
        
        #Explaining Vola of Stock with Market: 
        X = reg_df["Equity Return"]
        X = sm.add_constant(X)
        model = sm.OLS(endog = reg_df["Risk_Premium_Beta"], exog = X , missing = "drop")
        results = model.fit()
        regression_stats_dict["last_year_vola_explained_by_market"]=results.params["Equity Return"]
        
        #Make dataframe and store it to list
        market_data_df = pd.DataFrame.from_dict(regression_stats_dict,orient='index')
        market_data_df.columns = [quaterly_report_period]
        market_data_list.append(market_data_df)

    #Get the accounting data 
    entity_num_quarterly = num[num["adsh"] == quaterly_report_adsh] #fetch report
    entity_num_quarterly_period = entity_num_quarterly[(entity_num_quarterly["ddate"]==quaterly_report_period)&
                                                       entity_num_quarterly["qtrs"].isin([0,1])] #Only get the data for the last quarter
    date_list.append(quaterly_report_period)
    report_list.append(entity_num_quarterly_period)



    if report_type == "10-K":
        annual_report_list.append(entity_num_quarterly[(entity_num_quarterly["ddate"]==quaterly_report_period)&
                                                        entity_num_quarterly["qtrs"].isin([0,4])])#Get last year data
        annual_report_date_list.append(quaterly_report_period)
        print("Also saving this as 10-K report")

    print("################################################## Next Period#################################################")


annual_report_long = pd.concat(annual_report_list)
annual_reports_complete_long = pd.pivot_table(annual_report_long, index= "ddate",columns = "tag", values="value")
if len(share_price_ts)!=0:
    market_data_results_wide = pd.concat(market_data_list,axis=1)
    market_data_results_long = market_data_results_wide.transpose()
    complete_data_long = pd.merge(annual_reports_complete_long,market_data_results_long, left_index=True, right_index=True)
    complete_data_long.index = pd.DatetimeIndex(complete_data_long.index)
    complete_data_long.index.name = str(name)+"_"+str(entity_sub["sic"].iloc[0])
    complete_data_long.transpose().to_excel("Output/"+str(name)+"_complete.xlsx")


elapsed_time = time.process_time() - t
print("Processing Time in Minutes: "+str(elapsed_time/60))
print(str(name)+" Done")
print("IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII")
# Out:
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# Starting with: APPLE INC
# APPLE INC not in 2009q1
# APPLE INC not in 2009q2
# Report that was published in: 2009q3
#    form    fy  fp   fye    period                  adsh               accepted
# 5  10-Q  2009  Q3  0930  20090630  0001193125-09-153165  2009-07-22 16:42:00.0
# Fetching Report that was published in :  20090630
# Equity Market Stats for 1Y since Filing on: 2009-07-22 16:42:00
# const                0.007388
# Risk-Free Return    -0.159513
# Risk_Premium_Beta    1.106974
# dtype: float64
# With T-Values:
# const                1.690561
# Risk-Free Return    -0.063060
# Risk_Premium_Beta    6.222601
# dtype: float64
# Information Ratio last year: 0.441961483720842
# 1Y Historic Equity Market Stats (filing between): 2008-07-23 16:42:00 and 2009-07-22 16:42:00
# const                0.011840
# Risk-Free Return    -8.865317
# Risk_Premium_Beta    0.716709
# dtype: float64
# With T-Values:
# const                1.663990
# Risk-Free Return    -2.748402
# Risk_Premium_Beta    5.366146
# dtype: float64
# Information Ratio next year:0.4507264522983901
# ################################################## Next Period#################################################
# Report that was published in: 2009q4
#     form    fy  fp   fye    period                  adsh  \
# 67  10-K  2009  FY  0930  20090930  0001193125-09-214859
#
#                  accepted
# 67  2009-10-27 16:18:00.0
# No 10-Q in 2009q4, fetching 10-K instead
# Fetching Report that was published in :  20090930
# Equity Market Stats for 1Y since Filing on: 2009-10-27 16:18:00
# const                0.005583
# Risk-Free Return     0.679455
# Risk_Premium_Beta    1.337026
# dtype: float64
# With T-Values:
# const                1.369564
# Risk-Free Return     0.258157
# Risk_Premium_Beta    8.305163
# dtype: float64
# Information Ratio last year: 0.3581113076895883
# 1Y Historic Equity Market Stats (filing between): 2008-10-28 16:18:00 and 2009-10-27 16:18:00
# const                0.011056
# Risk-Free Return    -0.485533
# Risk_Premium_Beta    0.938926
# dtype: float64
# With T-Values:
# const                2.106662
# Risk-Free Return    -0.184937
# Risk_Premium_Beta    7.836330
# dtype: float64
# Information Ratio next year:0.5490379653006249
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2010q1
#        form    fy  fp   fye    period                  adsh  \
# 482    10-Q  2010  Q1  0930  20091231  0001193125-10-012085
# 483  10-K/A  2009  FY  0930  20090930  0001193125-10-012091
#
#                   accepted
# 482  2010-01-25 16:24:00.0
# 483  2010-01-25 16:26:00.0
# Fetching Report that was published in :  20091231
# Equity Market Stats for 1Y since Filing on: 2010-01-25 16:24:00
# const                0.004141
# Risk-Free Return     3.985120
# Risk_Premium_Beta    1.413729
# dtype: float64
# With T-Values:
# const                1.077473
# Risk-Free Return     1.368857
# Risk_Premium_Beta    8.700632
# dtype: float64
# Information Ratio last year: 0.2735708773801681
# 1Y Historic Equity Market Stats (filing between): 2009-01-26 16:24:00 and 2010-01-25 16:24:00
# const                0.011198
# Risk-Free Return    -1.936890
# Risk_Premium_Beta    0.921582
# dtype: float64
# With T-Values:
# const                2.627227
# Risk-Free Return    -0.928669
# Risk_Premium_Beta    7.247782
# dtype: float64
# Information Ratio next year:0.6842673012435552
# ################################################## Next Period#################################################
# Report that was published in: 2010q2
#     form    fy  fp   fye    period                  adsh  \
# 16  10-Q  2010  Q2  0930  20100331  0001193125-10-088957
#
#                  accepted
# 16  2010-04-21 16:39:00.0
# Fetching Report that was published in :  20100331
# Equity Market Stats for 1Y since Filing on: 2010-04-21 16:39:00
# const                0.002238
# Risk-Free Return     1.697654
# Risk_Premium_Beta    1.397777
# dtype: float64
# With T-Values:
# const                0.557044
# Risk-Free Return     0.584112
# Risk_Premium_Beta    8.141850
# dtype: float64
# Information Ratio last year: 0.13865860969542915
# 1Y Historic Equity Market Stats (filing between): 2009-04-22 16:39:00 and 2010-04-21 16:39:00
# const                0.008669
# Risk-Free Return    -1.328967
# Risk_Premium_Beta    0.858520
# dtype: float64
# With T-Values:
# const                1.965655
# Risk-Free Return    -0.591181
# Risk_Premium_Beta    4.481747
# dtype: float64
# Information Ratio next year:0.533362931281297
# ################################################## Next Period#################################################
# Report that was published in: 2010q3
#     form    fy  fp   fye    period                  adsh  \
# 27  10-Q  2010  Q3  0930  20100630  0001193125-10-162840
#
#                  accepted
# 27  2010-07-21 16:38:00.0
# Fetching Report that was published in :  20100630
# Equity Market Stats for 1Y since Filing on: 2010-07-21 16:38:00
# const                0.001332
# Risk-Free Return     2.353827
# Risk_Premium_Beta    1.263662
# dtype: float64
# With T-Values:
# const                0.337256
# Risk-Free Return     0.846635
# Risk_Premium_Beta    6.000895
# dtype: float64
# Information Ratio last year: 0.08564941984712872
# 1Y Historic Equity Market Stats (filing between): 2009-07-22 16:38:00 and 2010-07-21 16:38:00
# const                0.007388
# Risk-Free Return    -0.159513
# Risk_Premium_Beta    1.106974
# dtype: float64
# With T-Values:
# const                1.690561
# Risk-Free Return    -0.063060
# Risk_Premium_Beta    6.222601
# dtype: float64
# Information Ratio next year:0.441961483720842
# ################################################## Next Period#################################################
# Report that was published in: 2010q4
#      form    fy  fp   fye    period                  adsh  \
# 167  10-K  2010  FY  0930  20100930  0001193125-10-238044
#
#                   accepted
# 167  2010-10-27 16:36:00.0
# No 10-Q in 2010q4, fetching 10-K instead
# Fetching Report that was published in :  20100930
# Equity Market Stats for 1Y since Filing on: 2010-10-27 16:36:00
# const                0.004004
# Risk-Free Return     1.396379
# Risk_Premium_Beta    0.936369
# dtype: float64
# With T-Values:
# const                0.841384
# Risk-Free Return     0.393430
# Risk_Premium_Beta    5.176277
# dtype: float64
# Information Ratio last year: 0.20517097311792268
# 1Y Historic Equity Market Stats (filing between): 2009-10-28 16:36:00 and 2010-10-27 16:36:00
# const                0.005583
# Risk-Free Return     0.679455
# Risk_Premium_Beta    1.337026
# dtype: float64
# With T-Values:
# const                1.369564
# Risk-Free Return     0.258157
# Risk_Premium_Beta    8.305163
# dtype: float64
# Information Ratio next year:0.3581113076895883
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2011q1
#       form    fy  fp   fye    period                  adsh  \
# 1454  10-Q  2011  Q1  0930  20101231  0001193125-11-010144
#
#                    accepted
# 1454  2011-01-19 16:33:00.0
# Fetching Report that was published in :  20101231
# Equity Market Stats for 1Y since Filing on: 2011-01-19 16:33:00
# const                0.003962
# Risk-Free Return     0.710153
# Risk_Premium_Beta    0.903063
# dtype: float64
# With T-Values:
# const                0.815962
# Risk-Free Return     0.170946
# Risk_Premium_Beta    5.578578
# dtype: float64
# Information Ratio last year: 0.20221462605033394
# 1Y Historic Equity Market Stats (filing between): 2010-01-20 16:33:00 and 2011-01-19 16:33:00
# const                0.005524
# Risk-Free Return     3.237272
# Risk_Premium_Beta    1.370564
# dtype: float64
# With T-Values:
# const                1.482645
# Risk-Free Return     1.146341
# Risk_Premium_Beta    8.830551
# dtype: float64
# Information Ratio next year:0.3818854399883342
# ################################################## Next Period#################################################
# Report that was published in: 2011q2
#     form    fy  fp   fye    period                  adsh  \
# 86  10-Q  2011  Q2  0930  20110331  0001193125-11-104388
#
#                  accepted
# 86  2011-04-21 06:14:00.0
# Fetching Report that was published in :  20110331
# Equity Market Stats for 1Y since Filing on: 2011-04-21 06:14:00
# const                0.010609
# Risk-Free Return     1.123373
# Risk_Premium_Beta    0.862075
# dtype: float64
# With T-Values:
# const                2.092265
# Risk-Free Return     0.195938
# Risk_Premium_Beta    5.145106
# dtype: float64
# Information Ratio last year: 0.5501458207689579
# 1Y Historic Equity Market Stats (filing between): 2010-04-22 06:14:00 and 2011-04-21 06:14:00
# const                0.003116
# Risk-Free Return     1.739339
# Risk_Premium_Beta    1.415461
# dtype: float64
# With T-Values:
# const                0.765290
# Risk-Free Return     0.586005
# Risk_Premium_Beta    8.086700
# dtype: float64
# Information Ratio next year:0.18988849990134596
# ################################################## Next Period#################################################
# Report that was published in: 2011q3
#     form    fy  fp   fye    period                  adsh  \
# 67  10-Q  2011  Q3  0930  20110630  0001193125-11-192493
#
#                  accepted
# 67  2011-07-20 16:32:00.0
# Fetching Report that was published in :  20110630
# Equity Market Stats for 1Y since Filing on: 2011-07-20 16:32:00
# const                0.009288
# Risk-Free Return     4.023290
# Risk_Premium_Beta    0.933251
# dtype: float64
# With T-Values:
# const                1.824850
# Risk-Free Return     0.512457
# Risk_Premium_Beta    5.536195
# dtype: float64
# Information Ratio last year: 0.4605146143657581
# 1Y Historic Equity Market Stats (filing between): 2010-07-21 16:32:00 and 2011-07-20 16:32:00
# const                0.001332
# Risk-Free Return     2.353827
# Risk_Premium_Beta    1.263662
# dtype: float64
# With T-Values:
# const                0.337256
# Risk-Free Return     0.846635
# Risk_Premium_Beta    6.000895
# dtype: float64
# Information Ratio next year:0.08564941984712872
# ################################################## Next Period#################################################
# Report that was published in: 2011q4
#      form    fy  fp   fye    period                  adsh  \
# 521  10-K  2011  FY  0930  20110930  0001193125-11-282113
#
#                   accepted
# 521  2011-10-26 16:35:00.0
# No 10-Q in 2011q4, fetching 10-K instead
# Fetching Report that was published in :  20110930
# Equity Market Stats for 1Y since Filing on: 2011-10-26 16:35:00
# const                0.005638
# Risk-Free Return     4.780327
# Risk_Premium_Beta    0.971873
# dtype: float64
# With T-Values:
# const                1.295236
# Risk-Free Return     0.608940
# Risk_Premium_Beta    4.808342
# dtype: float64
# Information Ratio last year: 0.3227558200258706
# 1Y Historic Equity Market Stats (filing between): 2010-10-27 16:35:00 and 2011-10-26 16:35:00
# const                0.004004
# Risk-Free Return     1.396379
# Risk_Premium_Beta    0.936369
# dtype: float64
# With T-Values:
# const                0.841384
# Risk-Free Return     0.393430
# Risk_Premium_Beta    5.176277
# dtype: float64
# Information Ratio next year:0.20517097311792268
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2012q1
#       form    fy  fp   fye    period                  adsh  \
# 6918  10-Q  2012  Q1  0930  20111231  0001193125-12-023398
#
#                    accepted
# 6918  2012-01-25 16:42:00.0
# Fetching Report that was published in :  20111231
# Equity Market Stats for 1Y since Filing on: 2012-01-25 16:42:00
# const                0.000867
# Risk-Free Return     1.033254
# Risk_Premium_Beta    1.160341
# dtype: float64
# With T-Values:
# const                0.171462
# Risk-Free Return     0.101664
# Risk_Premium_Beta    3.814601
# dtype: float64
# Information Ratio last year: 0.04179529701367348
# 1Y Historic Equity Market Stats (filing between): 2011-01-26 16:42:00 and 2012-01-25 16:42:00
# const                0.004878
# Risk-Free Return    -0.118146
# Risk_Premium_Beta    0.868647
# dtype: float64
# With T-Values:
# const                1.025336
# Risk-Free Return    -0.028920
# Risk_Premium_Beta    5.490113
# dtype: float64
# Information Ratio next year:0.2565142493235193
# ################################################## Next Period#################################################
# Report that was published in: 2012q2
#       form    fy  fp   fye    period                  adsh  \
# 1403  10-Q  2012  Q2  0930  20120331  0001193125-12-182321
#
#                    accepted
# 1403  2012-04-25 17:01:00.0
# Fetching Report that was published in :  20120331
# Equity Market Stats for 1Y since Filing on: 2012-04-25 17:01:00
# const                -0.010780
# Risk-Free Return     13.250689
# Risk_Premium_Beta     1.282735
# dtype: float64
# With T-Values:
# const               -2.020522
# Risk-Free Return     1.057428
# Risk_Premium_Beta    4.101604
# dtype: float64
# Information Ratio last year: -0.46703651094084764
# 1Y Historic Equity Market Stats (filing between): 2011-04-27 17:01:00 and 2012-04-25 17:01:00
# const                0.009357
# Risk-Free Return     0.795636
# Risk_Premium_Beta    0.851033
# dtype: float64
# With T-Values:
# const                1.806189
# Risk-Free Return     0.134828
# Risk_Premium_Beta    4.935460
# dtype: float64
# Information Ratio next year:0.46778900114130056
# ################################################## Next Period#################################################
# Report that was published in: 2012q3
#      form    fy  fp   fye    period                  adsh  \
# 670  10-Q  2012  Q3  0930  20120630  0001193125-12-314552
#
#                   accepted
# 670  2012-07-25 16:40:00.0
# Fetching Report that was published in :  20120630
# Equity Market Stats for 1Y since Filing on: 2012-07-25 16:40:00
# const               -0.011415
# Risk-Free Return    -1.027888
# Risk_Premium_Beta    1.228382
# dtype: float64
# With T-Values:
# const               -1.987662
# Risk-Free Return    -0.102114
# Risk_Premium_Beta    3.435825
# dtype: float64
# Information Ratio last year: -0.4631666323037714
# 1Y Historic Equity Market Stats (filing between): 2011-07-27 16:40:00 and 2012-07-25 16:40:00
# const                0.007841
# Risk-Free Return     5.242083
# Risk_Premium_Beta    0.919185
# dtype: float64
# With T-Values:
# const                1.559029
# Risk-Free Return     0.681376
# Risk_Premium_Beta    5.565599
# dtype: float64
# Information Ratio next year:0.39346229588965986
# ################################################## Next Period#################################################
# Report that was published in: 2012q4
#       form    fy  fp   fye    period                  adsh  \
# 1326  10-K  2012  FY  0930  20120930  0001193125-12-444068
#
#                    accepted
# 1326  2012-10-31 17:07:00.0
# No 10-Q in 2012q4, fetching 10-K instead
# Fetching Report that was published in :  20120930
# Equity Market Stats for 1Y since Filing on: 2012-10-31 17:07:00
# const               -0.005160
# Risk-Free Return    -8.052786
# Risk_Premium_Beta    0.917898
# dtype: float64
# With T-Values:
# const               -0.790711
# Risk-Free Return    -0.847472
# Risk_Premium_Beta    2.282419
# dtype: float64
# Information Ratio last year: -0.1916170856721482
# 1Y Historic Equity Market Stats (filing between): 2011-11-02 17:07:00 and 2012-10-31 17:07:00
# const                0.005841
# Risk-Free Return     4.861384
# Risk_Premium_Beta    0.996455
# dtype: float64
# With T-Values:
# const                1.356238
# Risk-Free Return     0.623097
# Risk_Premium_Beta    4.849242
# dtype: float64
# Information Ratio next year:0.33562646862626455
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2013q1
#      form    fy  fp   fye    period                  adsh  \
# 563  10-Q  2013  Q1  0930  20121231  0001193125-13-022339
#
#                   accepted
# 563  2013-01-24 17:02:00.0
# Fetching Report that was published in :  20121231
# Equity Market Stats for 1Y since Filing on: 2013-01-24 17:02:00
# const                0.000607
# Risk-Free Return    -2.386403
# Risk_Premium_Beta    0.496666
# dtype: float64
# With T-Values:
# const                0.097555
# Risk-Free Return    -0.266815
# Risk_Premium_Beta    1.087168
# dtype: float64
# Information Ratio last year: 0.02454630214765144
# 1Y Historic Equity Market Stats (filing between): 2012-01-26 17:02:00 and 2013-01-24 17:02:00
# const                0.000867
# Risk-Free Return     1.033254
# Risk_Premium_Beta    1.160341
# dtype: float64
# With T-Values:
# const                0.171462
# Risk-Free Return     0.101664
# Risk_Premium_Beta    3.814601
# dtype: float64
# Information Ratio next year:0.04179529701367348
# ################################################## Next Period#################################################
# Report that was published in: 2013q2
#       form    fy  fp   fye    period                  adsh  \
# 1740  10-Q  2013  Q2  0930  20130331  0001193125-13-168288
# 1761   8-K  2012  FY  0930  20120930  0001193125-13-170623
#
#                    accepted
# 1740  2013-04-23 21:29:00.0
# 1761  2013-04-24 17:06:00.0
# Fetching Report that was published in :  20130331
# Equity Market Stats for 1Y since Filing on: 2013-04-23 21:29:00
# const                0.005443
# Risk-Free Return    -6.100432
# Risk_Premium_Beta    0.410314
# dtype: float64
# With T-Values:
# const                1.064282
# Risk-Free Return    -0.934730
# Risk_Premium_Beta    1.199204
# dtype: float64
# Information Ratio last year: 0.2695802695598971
# 1Y Historic Equity Market Stats (filing between): 2012-04-24 21:29:00 and 2013-04-23 21:29:00
# const                -0.010780
# Risk-Free Return     13.250689
# Risk_Premium_Beta     1.282735
# dtype: float64
# With T-Values:
# const               -2.020522
# Risk-Free Return     1.057428
# Risk_Premium_Beta    4.101604
# dtype: float64
# Information Ratio next year:-0.46703651094084764
# ################################################## Next Period#################################################
# Report that was published in: 2013q3
#      form    fy  fp   fye    period                  adsh  \
# 708  10-Q  2013  Q3  0930  20130630  0001193125-13-300670
#
#                   accepted
# 708  2013-07-24 17:02:00.0
# Fetching Report that was published in :  20130630
# Equity Market Stats for 1Y since Filing on: 2013-07-24 17:02:00
# const                0.009726
# Risk-Free Return    -7.557558
# Risk_Premium_Beta    0.102130
# dtype: float64
# With T-Values:
# const                2.049602
# Risk-Free Return    -1.111257
# Risk_Premium_Beta    0.279577
# dtype: float64
# Information Ratio last year: 0.5354398807417757
# 1Y Historic Equity Market Stats (filing between): 2012-07-25 17:02:00 and 2013-07-24 17:02:00
# const               -0.011415
# Risk-Free Return    -1.027888
# Risk_Premium_Beta    1.228382
# dtype: float64
# With T-Values:
# const               -1.987662
# Risk-Free Return    -0.102114
# Risk_Premium_Beta    3.435825
# dtype: float64
# Information Ratio next year:-0.4631666323037714
# ################################################## Next Period#################################################
# Report that was published in: 2013q4
#       form    fy  fp   fye    period                  adsh  \
# 1158  10-K  2013  FY  0930  20130930  0001193125-13-416534
#
#                    accepted
# 1158  2013-10-29 20:38:00.0
# No 10-Q in 2013q4, fetching 10-K instead
# Fetching Report that was published in :  20130930
# Equity Market Stats for 1Y since Filing on: 2013-10-29 20:38:00
# const                0.005692
# Risk-Free Return     0.448794
# Risk_Premium_Beta    0.721910
# dtype: float64
# With T-Values:
# const                1.376137
# Risk-Free Return     0.071833
# Risk_Premium_Beta    2.229227
# dtype: float64
# Information Ratio last year: 0.3559519154435442
# 1Y Historic Equity Market Stats (filing between): 2012-10-30 20:38:00 and 2013-10-29 20:38:00
# const               -0.005160
# Risk-Free Return    -8.052786
# Risk_Premium_Beta    0.917898
# dtype: float64
# With T-Values:
# const               -0.790711
# Risk-Free Return    -0.847472
# Risk_Premium_Beta    2.282419
# dtype: float64
# Information Ratio next year:-0.1916170856721482
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2014q1
#      form    fy  fp   fye    period                  adsh  \
# 661  10-Q  2014  Q1  0930  20131231  0001193125-14-024487
#
#                   accepted
# 661  2014-01-28 17:07:00.0
# Fetching Report that was published in :  20131231
# Equity Market Stats for 1Y since Filing on: 2014-01-28 17:07:00
# const                0.004520
# Risk-Free Return     3.144908
# Risk_Premium_Beta    1.119471
# dtype: float64
# With T-Values:
# const                1.056797
# Risk-Free Return     0.601223
# Risk_Premium_Beta    3.298271
# dtype: float64
# Information Ratio last year: 0.2752797834126994
# 1Y Historic Equity Market Stats (filing between): 2013-01-29 17:07:00 and 2014-01-28 17:07:00
# const                0.003410
# Risk-Free Return    -3.476862
# Risk_Premium_Beta    0.544081
# dtype: float64
# With T-Values:
# const                0.619432
# Risk-Free Return    -0.436511
# Risk_Premium_Beta    1.391856
# dtype: float64
# Information Ratio next year:0.15523603966565033
# ################################################## Next Period#################################################
# Report that was published in: 2014q2
#       form    fy  fp   fye    period                  adsh  \
# 1281  10-Q  2014  Q2  0930  20140331  0001193125-14-157311
#
#                    accepted
# 1281  2014-04-24 17:02:00.0
# Fetching Report that was published in :  20140331
# Equity Market Stats for 1Y since Filing on: 2014-04-24 17:02:00
# const                0.007232
# Risk-Free Return     4.328632
# Risk_Premium_Beta    1.080268
# dtype: float64
# With T-Values:
# const                1.868346
# Risk-Free Return     1.111269
# Risk_Premium_Beta    3.883586
# dtype: float64
# Information Ratio last year: 0.48324758772414794
# 1Y Historic Equity Market Stats (filing between): 2013-04-25 17:02:00 and 2014-04-24 17:02:00
# const                0.005443
# Risk-Free Return    -6.100432
# Risk_Premium_Beta    0.410314
# dtype: float64
# With T-Values:
# const                1.064282
# Risk-Free Return    -0.934730
# Risk_Premium_Beta    1.199204
# dtype: float64
# Information Ratio next year:0.2695802695598971
# ################################################## Next Period#################################################
# Report that was published in: 2014q3
#      form    fy  fp   fye    period                  adsh  \
# 583  10-Q  2014  Q3  0930  20140630  0001193125-14-277160
#
#                   accepted
# 583  2014-07-23 16:33:00.0
# Fetching Report that was published in :  20140630
# Equity Market Stats for 1Y since Filing on: 2014-07-23 16:33:00
# const                0.004228
# Risk-Free Return     3.700205
# Risk_Premium_Beta    1.159014
# dtype: float64
# With T-Values:
# const                1.223940
# Risk-Free Return     1.202660
# Risk_Premium_Beta    4.830314
# dtype: float64
# Information Ratio last year: 0.30366229858588173
# 1Y Historic Equity Market Stats (filing between): 2013-07-24 16:33:00 and 2014-07-23 16:33:00
# const                0.009726
# Risk-Free Return    -7.557558
# Risk_Premium_Beta    0.102130
# dtype: float64
# With T-Values:
# const                2.049602
# Risk-Free Return    -1.111257
# Risk_Premium_Beta    0.279577
# dtype: float64
# Information Ratio next year:0.5354398807417757
# ################################################## Next Period#################################################
# Report that was published in: 2014q4
#      form    fy  fp   fye    period                  adsh  \
# 775  10-K  2014  FY  0930  20140930  0001193125-14-383437
#
#                   accepted
# 775  2014-10-27 17:12:00.0
# No 10-Q in 2014q4, fetching 10-K instead
# Fetching Report that was published in :  20140930
# Equity Market Stats for 1Y since Filing on: 2014-10-27 17:12:00
# const                0.001523
# Risk-Free Return     0.638157
# Risk_Premium_Beta    1.235550
# dtype: float64
# With T-Values:
# const                0.407960
# Risk-Free Return     0.203716
# Risk_Premium_Beta    5.409765
# dtype: float64
# Information Ratio last year: 0.0982158261976275
# 1Y Historic Equity Market Stats (filing between): 2013-10-28 17:12:00 and 2014-10-27 17:12:00
# const                0.005692
# Risk-Free Return     0.448794
# Risk_Premium_Beta    0.721910
# dtype: float64
# With T-Values:
# const                1.376137
# Risk-Free Return     0.071833
# Risk_Premium_Beta    2.229227
# dtype: float64
# Information Ratio next year:0.3559519154435442
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2015q1
#      form    fy  fp   fye    period                  adsh  \
# 565  10-Q  2015  Q1  0930  20141231  0001193125-15-023697
# 566   8-K  2014  FY  0930  20140930  0001193125-15-023732
#
#                   accepted
# 565  2015-01-28 16:40:00.0
# 566  2015-01-28 16:49:00.0
# Fetching Report that was published in :  20141231
# Equity Market Stats for 1Y since Filing on: 2015-01-28 16:40:00
# const                0.000344
# Risk-Free Return     0.937909
# Risk_Premium_Beta    1.277858
# dtype: float64
# With T-Values:
# const                0.096146
# Risk-Free Return     0.304229
# Risk_Premium_Beta    6.687742
# dtype: float64
# Information Ratio last year: 0.02273317075542131
# 1Y Historic Equity Market Stats (filing between): 2014-01-29 16:40:00 and 2015-01-28 16:40:00
# const                0.004520
# Risk-Free Return     3.144908
# Risk_Premium_Beta    1.119471
# dtype: float64
# With T-Values:
# const                1.056797
# Risk-Free Return     0.601223
# Risk_Premium_Beta    3.298271
# dtype: float64
# Information Ratio next year:0.2752797834126994
# ################################################## Next Period#################################################
# Report that was published in: 2015q2
#       form    fy  fp   fye    period                  adsh  \
# 1356  10-Q  2015  Q2  0930  20150331  0001193125-15-153166
#
#                    accepted
# 1356  2015-04-28 17:01:00.0
# Fetching Report that was published in :  20150331
# Equity Market Stats for 1Y since Filing on: 2015-04-28 17:01:00
# const               -0.002938
# Risk-Free Return    -0.035518
# Risk_Premium_Beta    1.242835
# dtype: float64
# With T-Values:
# const               -0.824064
# Risk-Free Return    -0.011816
# Risk_Premium_Beta    6.851129
# dtype: float64
# Information Ratio last year: -0.19173006474846455
# 1Y Historic Equity Market Stats (filing between): 2014-04-29 17:01:00 and 2015-04-28 17:01:00
# const                0.005499
# Risk-Free Return     5.452692
# Risk_Premium_Beta    1.174982
# dtype: float64
# With T-Values:
# const                1.580488
# Risk-Free Return     1.568894
# Risk_Premium_Beta    4.763565
# dtype: float64
# Information Ratio next year:0.4081546242014866
# ################################################## Next Period#################################################
# Report that was published in: 2015q3
#      form    fy  fp   fye    period                  adsh  \
# 515  10-Q  2015  Q3  0930  20150630  0001193125-15-259935
#
#                   accepted
# 515  2015-07-22 17:01:00.0
# Fetching Report that was published in :  20150630
# Equity Market Stats for 1Y since Filing on: 2015-07-22 17:01:00
# const               -0.004148
# Risk-Free Return    -2.843718
# Risk_Premium_Beta    1.244728
# dtype: float64
# With T-Values:
# const               -1.014654
# Risk-Free Return    -0.837465
# Risk_Premium_Beta    6.238097
# dtype: float64
# Information Ratio last year: -0.2366746964592706
# 1Y Historic Equity Market Stats (filing between): 2014-07-23 17:01:00 and 2015-07-22 17:01:00
# const                0.004228
# Risk-Free Return     3.700205
# Risk_Premium_Beta    1.159014
# dtype: float64
# With T-Values:
# const                1.223940
# Risk-Free Return     1.202660
# Risk_Premium_Beta    4.830314
# dtype: float64
# Information Ratio next year:0.30366229858588173
# ################################################## Next Period#################################################
# Report that was published in: 2015q4
#      form    fy  fp   fye    period                  adsh  \
# 796  10-K  2015  FY  0930  20150930  0001193125-15-356351
#
#                   accepted
# 796  2015-10-28 16:31:00.0
# No 10-Q in 2015q4, fetching 10-K instead
# Fetching Report that was published in :  20150930
# Equity Market Stats for 1Y since Filing on: 2015-10-28 16:31:00
# const               -0.000629
# Risk-Free Return     0.403583
# Risk_Premium_Beta    1.286845
# dtype: float64
# With T-Values:
# const               -0.140365
# Risk-Free Return     0.106037
# Risk_Premium_Beta    5.160092
# dtype: float64
# Information Ratio last year: -0.033236061557505664
# 1Y Historic Equity Market Stats (filing between): 2014-10-29 16:31:00 and 2015-10-28 16:31:00
# const                0.001523
# Risk-Free Return     0.638157
# Risk_Premium_Beta    1.235550
# dtype: float64
# With T-Values:
# const                0.407960
# Risk-Free Return     0.203716
# Risk_Premium_Beta    5.409765
# dtype: float64
# Information Ratio next year:0.0982158261976275
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2016q1
#      form    fy  fp   fye    period                  adsh  \
# 481  10-Q  2016  Q1  0930  20151231  0001193125-16-439878
#
#                   accepted
# 481  2016-01-27 16:32:00.0
# Fetching Report that was published in :  20151231
# Equity Market Stats for 1Y since Filing on: 2016-01-27 16:32:00
# const                0.000118
# Risk-Free Return    -0.008076
# Risk_Premium_Beta    1.014089
# dtype: float64
# With T-Values:
# const                0.026356
# Risk-Free Return    -0.002273
# Risk_Premium_Beta    3.496108
# dtype: float64
# Information Ratio last year: 0.006483369002382382
# 1Y Historic Equity Market Stats (filing between): 2015-01-28 16:32:00 and 2016-01-27 16:32:00
# const                0.000344
# Risk-Free Return     0.937909
# Risk_Premium_Beta    1.277858
# dtype: float64
# With T-Values:
# const                0.096146
# Risk-Free Return     0.304229
# Risk_Premium_Beta    6.687742
# dtype: float64
# Information Ratio next year:0.02273317075542131
# ################################################## Next Period#################################################
# Report that was published in: 2016q2
#       form    fy  fp   fye    period                  adsh  \
# 1154  10-Q  2016  Q2  0930  20160331  0001193125-16-559625
#
#                    accepted
# 1154  2016-04-27 16:33:00.0
# Fetching Report that was published in :  20160331
# Equity Market Stats for 1Y since Filing on: 2016-04-27 16:33:00
# const                0.003869
# Risk-Free Return    -1.011028
# Risk_Premium_Beta    1.046352
# dtype: float64
# With T-Values:
# const                0.918298
# Risk-Free Return    -0.289633
# Risk_Premium_Beta    3.199535
# dtype: float64
# Information Ratio last year: 0.22829908124691722
# 1Y Historic Equity Market Stats (filing between): 2015-04-29 16:33:00 and 2016-04-27 16:33:00
# const               -0.002938
# Risk-Free Return    -0.035518
# Risk_Premium_Beta    1.242835
# dtype: float64
# With T-Values:
# const               -0.824064
# Risk-Free Return    -0.011816
# Risk_Premium_Beta    6.851129
# dtype: float64
# Information Ratio next year:-0.19173006474846455
# ################################################## Next Period#################################################
# Report that was published in: 2016q3
#      form    fy  fp   fye    period                  adsh  \
# 661  10-Q  2016  Q3  0930  20160630  0001628280-16-017809
#
#                   accepted
# 661  2016-07-27 16:33:00.0
# Fetching Report that was published in :  20160630
# Equity Market Stats for 1Y since Filing on: 2016-07-27 16:33:00
# const                0.006155
# Risk-Free Return     3.804938
# Risk_Premium_Beta    0.880047
# dtype: float64
# With T-Values:
# const                1.600874
# Risk-Free Return     1.102433
# Risk_Premium_Beta    2.640041
# dtype: float64
# Information Ratio last year: 0.4046423300170282
# 1Y Historic Equity Market Stats (filing between): 2015-07-29 16:33:00 and 2016-07-27 16:33:00
# const               -0.004013
# Risk-Free Return    -2.980925
# Risk_Premium_Beta    1.232977
# dtype: float64
# With T-Values:
# const               -0.977053
# Risk-Free Return    -0.874314
# Risk_Premium_Beta    6.093343
# dtype: float64
# Information Ratio next year:-0.22930178708828988
# ################################################## Next Period#################################################
# Report that was published in: 2016q4
#      form    fy  fp   fye    period                  adsh  \
# 650  10-K  2016  FY  0930  20160930  0001628280-16-020309
#
#                   accepted
# 650  2016-10-26 16:42:00.0
# No 10-Q in 2016q4, fetching 10-K instead
# Fetching Report that was published in :  20160930
# Equity Market Stats for 1Y since Filing on: 2016-10-26 16:42:00
# const                0.002524
# Risk-Free Return     3.986492
# Risk_Premium_Beta    0.905475
# dtype: float64
# With T-Values:
# const                0.775362
# Risk-Free Return     1.312379
# Risk_Premium_Beta    3.054966
# dtype: float64
# Information Ratio last year: 0.19987242153760046
# 1Y Historic Equity Market Stats (filing between): 2015-10-28 16:42:00 and 2016-10-26 16:42:00
# const               -0.000629
# Risk-Free Return     0.403583
# Risk_Premium_Beta    1.286845
# dtype: float64
# With T-Values:
# const               -0.140365
# Risk-Free Return     0.106037
# Risk_Premium_Beta    5.160092
# dtype: float64
# Information Ratio next year:-0.033236061557505664
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2017q1
#      form    fy  fp   fye    period                  adsh  \
# 590  10-Q  2017  Q1  0930  20161231  0001628280-17-000717
#
#                   accepted
# 590  2017-02-01 16:33:00.0
# Fetching Report that was published in :  20161231
# Equity Market Stats for 1Y since Filing on: 2017-02-01 16:33:00
# const                0.003845
# Risk-Free Return     4.504621
# Risk_Premium_Beta    0.749056
# dtype: float64
# With T-Values:
# const                0.945504
# Risk-Free Return     1.078253
# Risk_Premium_Beta    1.702162
# dtype: float64
# Information Ratio last year: 0.2608759330915103
# 1Y Historic Equity Market Stats (filing between): 2016-02-03 16:33:00 and 2017-02-01 16:33:00
# const                0.000812
# Risk-Free Return     1.722578
# Risk_Premium_Beta    1.114455
# dtype: float64
# With T-Values:
# const                0.188790
# Risk-Free Return     0.490245
# Risk_Premium_Beta    3.940155
# dtype: float64
# Information Ratio next year:0.04648518479860233
# ################################################## Next Period#################################################
# Report that was published in: 2017q2
#       form    fy  fp   fye    period                  adsh  \
# 2032  10-Q  2017  Q2  0930  20170331  0001628280-17-004790
#
#                    accepted
# 2032  2017-05-03 16:32:00.0
# Fetching Report that was published in :  20170331
# Equity Market Stats for 1Y since Filing on: 2017-05-03 16:32:00
# const                0.000649
# Risk-Free Return     9.199819
# Risk_Premium_Beta    1.219019
# dtype: float64
# With T-Values:
# const                0.166894
# Risk-Free Return     1.740105
# Risk_Premium_Beta    4.813041
# dtype: float64
# Information Ratio last year: 0.03994007042279343
# 1Y Historic Equity Market Stats (filing between): 2016-05-04 16:32:00 and 2017-05-03 16:32:00
# const                0.006108
# Risk-Free Return    -0.186815
# Risk_Premium_Beta    0.881585
# dtype: float64
# With T-Values:
# const                1.668493
# Risk-Free Return    -0.061965
# Risk_Premium_Beta    3.111134
# dtype: float64
# Information Ratio next year:0.4227083639449564
# ################################################## Next Period#################################################
# Report that was published in: 2017q3
#       form    fy  fp   fye    period                  adsh  \
# 1197  10-Q  2017  Q3  0930  20170630  0000320193-17-000009
#
#                    accepted
# 1197  2017-08-02 16:31:00.0
# Fetching Report that was published in :  20170630
# Equity Market Stats for 1Y since Filing on: 2017-08-02 16:31:00
# const                0.002585
# Risk-Free Return     6.687324
# Risk_Premium_Beta    1.110748
# dtype: float64
# With T-Values:
# const                0.587313
# Risk-Free Return     1.090559
# Risk_Premium_Beta    3.901107
# dtype: float64
# Information Ratio last year: 0.14238063580514546
# 1Y Historic Equity Market Stats (filing between): 2016-08-03 16:31:00 and 2017-08-02 16:31:00
# const                0.005081
# Risk-Free Return     2.908517
# Risk_Premium_Beta    0.875663
# dtype: float64
# With T-Values:
# const                1.366005
# Risk-Free Return     0.859646
# Risk_Premium_Beta    2.711165
# dtype: float64
# Information Ratio next year:0.3424161108672779
# ################################################## Next Period#################################################
# Report that was published in: 2017q4
#       form    fy  fp   fye    period                  adsh  \
# 1821  10-K  2017  FY  0930  20170930  0000320193-17-000070
#
#                    accepted
# 1821  2017-11-03 08:02:00.0
# No 10-Q in 2017q4, fetching 10-K instead
# Fetching Report that was published in :  20170930
# Equity Market Stats for 1Y since Filing on: 2017-11-03 08:02:00
# const                 0.002787
# Risk-Free Return     11.457447
# Risk_Premium_Beta     1.067586
# dtype: float64
# With T-Values:
# const                0.604024
# Risk-Free Return     1.763924
# Risk_Premium_Beta    3.897611
# dtype: float64
# Information Ratio last year: 0.14511558198804222
# 1Y Historic Equity Market Stats (filing between): 2016-11-04 08:02:00 and 2017-11-03 08:02:00
# const                0.006270
# Risk-Free Return     3.119717
# Risk_Premium_Beta    0.680638
# dtype: float64
# With T-Values:
# const                1.775597
# Risk-Free Return     0.959939
# Risk_Premium_Beta    2.075706
# dtype: float64
# Information Ratio next year:0.47869590338145135
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2018q1
#      form    fy  fp   fye    period                  adsh  \
# 610  10-Q  2018  Q1  0930  20171231  0000320193-18-000007
#
#                   accepted
# 610  2018-02-02 08:01:00.0
# Fetching Report that was published in :  20171231
# Equity Market Stats for 1Y since Filing on: 2018-02-02 08:01:00
# const                0.000655
# Risk-Free Return     3.600796
# Risk_Premium_Beta    1.060082
# dtype: float64
# With T-Values:
# const                0.121122
# Risk-Free Return     0.643587
# Risk_Premium_Beta    4.657051
# dtype: float64
# Information Ratio last year: 0.03091479817864794
# 1Y Historic Equity Market Stats (filing between): 2017-02-03 08:01:00 and 2018-02-02 08:01:00
# const                0.000887
# Risk-Free Return     6.226105
# Risk_Premium_Beta    1.074529
# dtype: float64
# With T-Values:
# const                0.242531
# Risk-Free Return     1.626816
# Risk_Premium_Beta    3.151302
# dtype: float64
# Information Ratio next year:0.061251480476812614
# ################################################## Next Period#################################################
# Report that was published in: 2018q2
#       form    fy  fp   fye    period                  adsh  \
# 2029  10-Q  2018  Q2  0930  20180331  0000320193-18-000070
#
#                    accepted
# 2029  2018-05-02 16:32:00.0
# Fetching Report that was published in :  20180331
# Equity Market Stats for 1Y since Filing on: 2018-05-02 16:32:00
# const                0.000544
# Risk-Free Return     5.571985
# Risk_Premium_Beta    1.046617
# dtype: float64
# With T-Values:
# const                0.095483
# Risk-Free Return     1.112786
# Risk_Premium_Beta    4.334481
# dtype: float64
# Information Ratio last year: 0.02652682967608431
# 1Y Historic Equity Market Stats (filing between): 2017-05-03 16:32:00 and 2018-05-02 16:32:00
# const                0.000649
# Risk-Free Return     9.199819
# Risk_Premium_Beta    1.219019
# dtype: float64
# With T-Values:
# const                0.166894
# Risk-Free Return     1.740105
# Risk_Premium_Beta    4.813041
# dtype: float64
# Information Ratio next year:0.03994007042279343
# ################################################## Next Period#################################################
# Report that was published in: 2018q3
#       form    fy  fp   fye    period                  adsh  \
# 1101  10-Q  2018  Q3  0930  20180630  0000320193-18-000100
#
#                    accepted
# 1101  2018-08-01 16:32:00.0
# Fetching Report that was published in :  20180630
# Equity Market Stats for 1Y since Filing on: 2018-08-01 16:32:00
# const               -0.002343
# Risk-Free Return     5.180505
# Risk_Premium_Beta    1.211763
# dtype: float64
# With T-Values:
# const               -0.440939
# Risk-Free Return     1.295087
# Risk_Premium_Beta    5.884030
# dtype: float64
# Information Ratio last year: -0.12396303171857441
# 1Y Historic Equity Market Stats (filing between): 2017-08-02 16:32:00 and 2018-08-01 16:32:00
# const                0.002585
# Risk-Free Return     6.687324
# Risk_Premium_Beta    1.110748
# dtype: float64
# With T-Values:
# const                0.587313
# Risk-Free Return     1.090559
# Risk_Premium_Beta    3.901107
# dtype: float64
# Information Ratio next year:0.14238063580514546
# ################################################## Next Period#################################################
# Report that was published in: 2018q4
#       form    fy  fp   fye    period                  adsh  \
# 1828  10-K  2018  FY  0930  20180930  0000320193-18-000145
#
#                    accepted
# 1828  2018-11-05 08:02:00.0
# No 10-Q in 2018q4, fetching 10-K instead
# Fetching Report that was published in :  20180930
# Equity Market Stats for 1Y since Filing on: 2018-11-05 08:02:00
# const               -0.000049
# Risk-Free Return     3.094946
# Risk_Premium_Beta    1.331437
# dtype: float64
# With T-Values:
# const               -0.011492
# Risk-Free Return     1.243763
# Risk_Premium_Beta    7.452511
# dtype: float64
# Information Ratio last year: -0.003176863658114353
# 1Y Historic Equity Market Stats (filing between): 2017-11-06 08:02:00 and 2018-11-05 08:02:00
# const                 0.002787
# Risk-Free Return     11.457447
# Risk_Premium_Beta     1.067586
# dtype: float64
# With T-Values:
# const                0.604024
# Risk-Free Return     1.763924
# Risk_Premium_Beta    3.897611
# dtype: float64
# Information Ratio next year:0.14511558198804222
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2019q1
#      form    fy  fp   fye    period                  adsh  \
# 262  10-Q  2019  Q1  0930  20181231  0000320193-19-000010
#
#                   accepted
# 262  2019-01-30 16:32:00.0
# Fetching Report that was published in :  20181231
# Equity Market Stats for 1Y since Filing on: 2019-01-30 16:32:00
# const                0.006930
# Risk-Free Return     3.203805
# Risk_Premium_Beta    1.387292
# dtype: float64
# With T-Values:
# const                2.028898
# Risk-Free Return     1.587357
# Risk_Premium_Beta    6.616001
# dtype: float64
# Information Ratio last year: 0.5983062523638331
# 1Y Historic Equity Market Stats (filing between): 2018-01-31 16:32:00 and 2019-01-30 16:32:00
# const               -0.000315
# Risk-Free Return     3.225652
# Risk_Premium_Beta    1.062212
# dtype: float64
# With T-Values:
# const               -0.059872
# Risk-Free Return     0.580346
# Risk_Premium_Beta    4.807765
# dtype: float64
# Information Ratio next year:-0.014879929993501658
# ################################################## Next Period#################################################
# Report that was published in: 2019q2
#       form    fy  fp   fye    period                  adsh  \
# 1909  10-Q  2019  Q2  0930  20190331  0000320193-19-000066
#
#                    accepted
# 1909  2019-05-01 16:32:00.0
# Fetching Report that was published in :  20190331
# Equity Market Stats for 1Y since Filing on: 2019-05-01 16:32:00
# const                0.007700
# Risk-Free Return     0.865777
# Risk_Premium_Beta    0.995146
# dtype: float64
# With T-Values:
# const                 2.172379
# Risk-Free Return      0.515202
# Risk_Premium_Beta    11.917425
# dtype: float64
# Information Ratio last year: 0.5965340969075611
# 1Y Historic Equity Market Stats (filing between): 2018-05-02 16:32:00 and 2019-05-01 16:32:00
# const                0.000544
# Risk-Free Return     5.571985
# Risk_Premium_Beta    1.046617
# dtype: float64
# With T-Values:
# const                0.095483
# Risk-Free Return     1.112786
# Risk_Premium_Beta    4.334481
# dtype: float64
# Information Ratio next year:0.02652682967608431
# ################################################## Next Period#################################################
# Report that was published in: 2019q3
#       form    fy   fp   fye    period                  adsh  \
# 1195  10-Q  2019   Q3  0930  20190630  0000320193-19-000076
# 8041   8-K   NaN  NaN  0930  20190831  0001193125-19-242975
# 8242   8-K   NaN  NaN  0930  20190831  0000320193-19-000093
#
#                    accepted
# 1195  2019-07-31 16:32:00.0
# 8041  2019-09-11 16:21:00.0
# 8242  2019-09-13 17:16:00.0
# Fetching Report that was published in :  20190630
# Equity Market Stats for 1Y since Filing on: 2019-07-31 16:32:00
# const                0.010651
# Risk-Free Return     0.558211
# Risk_Premium_Beta    0.881803
# dtype: float64
# With T-Values:
# const                 2.999749
# Risk-Free Return      0.312093
# Risk_Premium_Beta    10.786638
# dtype: float64
# Information Ratio last year: 0.8194362408221947
# 1Y Historic Equity Market Stats (filing between): 2018-08-01 16:32:00 and 2019-07-31 16:32:00
# const               -0.002343
# Risk-Free Return     5.180505
# Risk_Premium_Beta    1.211763
# dtype: float64
# With T-Values:
# const               -0.440939
# Risk-Free Return     1.295087
# Risk_Premium_Beta    5.884030
# dtype: float64
# Information Ratio next year:-0.12396303171857441
# ################################################## Next Period#################################################
# Report that was published in: 2019q4
#       form    fy   fp   fye    period                  adsh  \
# 2609   8-K   NaN  NaN  0930  20191031  0000320193-19-000117
# 3210  10-K  2019   FY  0930  20190930  0000320193-19-000119
# 9100   8-K   NaN  NaN  0930  20191031  0001193125-19-292676
#
#                    accepted
# 2609  2019-10-30 16:31:00.0
# 3210  2019-10-30 18:13:00.0
# 9100  2019-11-15 06:02:00.0
# No 10-Q in 2019q4, fetching 10-K instead
# Fetching Report that was published in :  20190930
# Equity Market Stats for 1Y since Filing on: 2019-10-30 18:13:00
# const                0.009883
# Risk-Free Return     0.943352
# Risk_Premium_Beta    0.916533
# dtype: float64
# With T-Values:
# const                1.909890
# Risk-Free Return     0.295443
# Risk_Premium_Beta    7.763505
# dtype: float64
# Information Ratio last year: 0.5246952917382708
# 1Y Historic Equity Market Stats (filing between): 2018-10-31 18:13:00 and 2019-10-30 18:13:00
# const               -0.002143
# Risk-Free Return     3.731384
# Risk_Premium_Beta    1.272206
# dtype: float64
# With T-Values:
# const               -0.470742
# Risk-Free Return     1.399962
# Risk_Premium_Beta    6.634487
# dtype: float64
# Information Ratio next year:-0.12709377116207252
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2020q1
#       form    fy   fp   fye    period                  adsh  \
# 1779   8-K   NaN  NaN  0930  20200131  0000320193-20-000008
# 1934  10-Q  2020   Q1  0930  20191231  0000320193-20-000010
# 4923   8-K   NaN  NaN  0930  20200229  0001193125-20-039203
# 7352   8-K   NaN  NaN  0930  20200229  0001193125-20-050884
#
#                    accepted
# 1779  2020-01-28 16:31:00.0
# 1934  2020-01-28 18:03:00.0
# 4923  2020-02-18 06:25:00.0
# 7352  2020-02-27 06:14:00.0
# Fetching Report that was published in :  20191231
# Equity Market Stats for 1Y since Filing on: 2020-01-28 18:03:00
# const                0.007676
# Risk-Free Return     1.336944
# Risk_Premium_Beta    0.934355
# dtype: float64
# With T-Values:
# const                1.392649
# Risk-Free Return     0.375327
# Risk_Premium_Beta    7.630508
# dtype: float64
# Information Ratio last year: 0.371692592657782
# 1Y Historic Equity Market Stats (filing between): 2019-01-29 18:03:00 and 2020-01-28 18:03:00
# const                0.006930
# Risk-Free Return     3.203805
# Risk_Premium_Beta    1.387292
# dtype: float64
# With T-Values:
# const                2.028898
# Risk-Free Return     1.587357
# Risk_Premium_Beta    6.616001
# dtype: float64
# Information Ratio next year:0.5983062523638331
# ################################################## Next Period#################################################
# Report that was published in: 2020q2
#       form    fy   fp   fye    period                  adsh  \
# 4044   8-K   NaN  NaN  0930  20200430  0000320193-20-000050
# 4604  10-Q  2020   Q2  0930  20200331  0000320193-20-000052
# 8704   8-K   NaN  NaN  0930  20200430  0001193125-20-139112
#
#                    accepted
# 4044  2020-04-30 16:31:00.0
# 4604  2020-04-30 18:03:00.0
# 8704  2020-05-11 16:31:00.0
# Fetching Report that was published in :  20200331
# Equity Market Stats for 1Y since Filing on: 2020-04-30 18:03:00
# const                 0.003036
# Risk-Free Return     30.908379
# Risk_Premium_Beta     1.062564
# dtype: float64
# With T-Values:
# const                0.579894
# Risk-Free Return     2.255712
# Risk_Premium_Beta    5.402261
# dtype: float64
# Information Ratio last year: 0.1492046962300508
# 1Y Historic Equity Market Stats (filing between): 2019-05-02 18:03:00 and 2020-04-30 18:03:00
# const                0.007700
# Risk-Free Return     0.865777
# Risk_Premium_Beta    0.995146
# dtype: float64
# With T-Values:
# const                 2.172379
# Risk-Free Return      0.515202
# Risk_Premium_Beta    11.917425
# dtype: float64
# Information Ratio next year:0.5965340969075611
# ################################################## Next Period#################################################
# Report that was published in: 2020q3
#        form    fy   fp   fye    period                  adsh  \
# 3049    8-K   NaN  NaN  0930  20200731  0000320193-20-000060
# 3567   10-Q  2020   Q3  0930  20200630  0000320193-20-000062
# 7052    8-K   NaN  NaN  0930  20200731  0001193125-20-213158
# 10735   8-K   NaN  NaN  0930  20200731  0001193125-20-225672
#
#                     accepted
# 3049   2020-07-30 18:55:00.0
# 3567   2020-07-30 19:29:00.0
# 7052   2020-08-07 17:20:00.0
# 10735  2020-08-20 16:31:00.0
# Fetching Report that was published in :  20200630
# Equity Market Stats for 1Y since Filing on: 2020-07-30 19:29:00
# const                -0.001401
# Risk-Free Return     24.402512
# Risk_Premium_Beta     1.266156
# dtype: float64
# With T-Values:
# const               -0.259503
# Risk-Free Return     1.529026
# Risk_Premium_Beta    5.461567
# dtype: float64
# Information Ratio last year: -0.06812462493509108
# 1Y Historic Equity Market Stats (filing between): 2019-08-01 19:29:00 and 2020-07-30 19:29:00
# const                0.010651
# Risk-Free Return     0.558211
# Risk_Premium_Beta    0.881803
# dtype: float64
# With T-Values:
# const                 2.999749
# Risk-Free Return      0.312093
# Risk_Premium_Beta    10.786638
# dtype: float64
# Information Ratio next year:0.8194362408221947
# ################################################## Next Period#################################################
# Report that was published in: 2020q4
#       form    fy   fp   fye    period                  adsh  \
# 3645   8-K   NaN  NaN  0930  20201031  0000320193-20-000094
# 4361  10-K  2020   FY  0930  20200930  0000320193-20-000096
#
#                    accepted
# 3645  2020-10-29 16:31:00.0
# 4361  2020-10-29 18:06:00.0
# No 10-Q in 2020q4, fetching 10-K instead
# Fetching Report that was published in :  20200930
# Equity Market Stats for 1Y since Filing on: 2020-10-29 18:06:00
# const                -0.005240
# Risk-Free Return     16.366678
# Risk_Premium_Beta     1.194851
# dtype: float64
# With T-Values:
# const               -1.099482
# Risk-Free Return     1.134562
# Risk_Premium_Beta    6.126564
# dtype: float64
# Information Ratio last year: -0.33745791820923154
# 1Y Historic Equity Market Stats (filing between): 2019-10-31 18:06:00 and 2020-10-29 18:06:00
# const                0.009883
# Risk-Free Return     0.943352
# Risk_Premium_Beta    0.916533
# dtype: float64
# With T-Values:
# const                1.909890
# Risk-Free Return     0.295443
# Risk_Premium_Beta    7.763505
# dtype: float64
# Information Ratio next year:0.5246952917382708
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2021q1
#       form    fy   fp   fye    period                  adsh  \
# 267    8-K   NaN  NaN  0930  20201231  0001193125-21-001982
# 2551  10-Q  2021   Q1  0930  20201231  0000320193-21-000010
# 3037   8-K   NaN  NaN  0930  20210131  0000320193-21-000009
# 5356   8-K   NaN  NaN  0930  20210131  0001193125-21-032394
# 9015   8-K   NaN  NaN  0930  20210228  0001193125-21-054710
#
#                    accepted
# 267   2021-01-05 16:32:00.0
# 2551  2021-01-27 18:03:00.0
# 3037  2021-01-27 16:31:00.0
# 5356  2021-02-08 16:31:00.0
# 9015  2021-02-24 16:31:00.0
# Fetching Report that was published in :  20201231
# Equity Market Stats for 1Y since Filing on: 2021-01-27 18:03:00
# const               -0.009990
# Risk-Free Return     5.095637
# Risk_Premium_Beta    1.206631
# dtype: float64
# With T-Values:
# const               -2.014975
# Risk-Free Return     0.319336
# Risk_Premium_Beta    4.712864
# dtype: float64
# Information Ratio last year: -0.7774645292062556
# 1Y Historic Equity Market Stats (filing between): 2020-01-29 18:03:00 and 2021-01-27 18:03:00
# const                0.007676
# Risk-Free Return     1.336944
# Risk_Premium_Beta    0.934355
# dtype: float64
# With T-Values:
# const                1.392649
# Risk-Free Return     0.375327
# Risk_Premium_Beta    7.630508
# dtype: float64
# Information Ratio next year:0.371692592657782
# ################################################## Next Period#################################################
# Processing Time in Minutes: 0.10755208333333334
# APPLE INC Done
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII

# %% [markdown]
# ## Setting Up an Annual Report process

# %% [markdown]
# The code needs to be 100% clear as of which date the numbers are and to what period they relate to and when they were published. In any anual report, you might find income numbers for the last quarter, the last 6 months, the last year and the previous year. In the loop I already exclude any periods that are not as of this date, so we have only the relevant dates per year here. The SEC "accepted" date is the date the numbers went public, so our regressions that give future returns since earnings release start there. Historic regressions end there.
#
# Context:
# * Quaterly reports can include unaudited statements on both balance sheet and income figures
# * Annual reports will usually include audited statements of both
# * Ideally, any process should be built around the minimum one can expect, i.e. the annual report and then be flexible in terms of using the quaterly reports to get more color

# %%
annual_report_long = pd.concat(annual_report_list)
annual_reports_complete_long = pd.pivot_table(annual_report_long, index= "ddate",columns = "tag", values="value")

annual_report_long = pd.concat(annual_report_list)
annual_reports_complete_long = pd.pivot_table(annual_report_long, index= "ddate",columns = "tag", values="value")
point_in_time_numbers_long = annual_report_long[annual_report_long["qtrs"]==0]
annual_numbers_long = annual_report_long[annual_report_long["qtrs"]==4]

point_in_time_numbers_wide = pd.pivot_table(point_in_time_numbers_long, index= "tag",columns = "ddate", values="value")
annual_numbers_wide = pd.pivot_table(annual_numbers_long, index= "tag",columns = "ddate", values="value")

point_in_time_numbers_long = pd.pivot_table(point_in_time_numbers_long, index= "ddate",columns = "tag", values="value")
annual_numbers_long = pd.pivot_table(annual_numbers_long, index= "ddate",columns = "tag", values="value")

market_data_results_wide = pd.concat(market_data_list,axis=1)
market_data_results_long = market_data_results_wide.transpose()
point_in_time_numbers_wide.to_excel("Output/"+str(name)+".xlsx")
complete_data_wide = pd.merge(annual_reports_complete_long,market_data_results_long, left_index=True, right_index=True).transpose()
complete_data_long = pd.merge(annual_numbers_long,market_data_results_long, left_index=True, right_index=True)
complete_data_long.index = pd.DatetimeIndex(complete_data_long.index)
complete_data_wide.to_excel("Output/"+str(name)+"_complete.xlsx")

# %% [markdown]
# ### This is relatively clean, but unordered data. Next we need to put this into a structure that we can use for a model.

# %%
time_all = time.process_time()
database = os.listdir("Database")

for sic_sector in firms_df["SIC"].unique():
    print("*********************************************************************************************************************")
    time_long = time.process_time()
    sector_name = str(firms_df.loc[firms_df["SIC"]==sic_sector,'Industry Title'].iloc[0])
    print("starting with: "+sector_name)
    os.mkdir("Output/Sectors/"+sector_name)
    for CIK in firms_df[firms_df["SIC"]==sic_sector]["CIK"].unique():

        t = time.process_time()
        #loading database again without zips
        report_list = list() #this will get all reports
        date_list = list()
        annual_report_list = list() #from this we can make a balance sheet file 
        annual_report_date_list = list() #dates for balance sheet file
        market_data_list = list() #market_data list for regressions etc. 
        share_price_ts = []

        name = str(firms_df[firms_df["CIK"]==CIK]["Firm"].iloc[0])
        print("IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII")
        print("Starting with: "+name)
        for file in database:
            dtypes = {"fy":str,
                      "fye":str,
                      "period":str,
                      "ddate":str,
                      "sic":str,
                     "cik":str}

            sub = subdict[file]
            report_type = "10-Q"

            if CIK not in sub["cik"].unique(): #If the firm we are looking for is not in the metadata for that quarter, we dont need to get into numbers
                print(name+" not in "+file)
                continue 

            entity_sub = sub[sub["cik"]==CIK]
            print("Report that was published in: "+file)
            print(entity_sub[["form","fy","fp","fye","period","adsh","accepted"]])
            if "10-Q" not in entity_sub["form"].unique(): #If our firm did not release a 10-Q, we check if we find the 10-K (they do not release both in the quarter after their year end)
                print("No 10-Q in "+file+", fetching 10-K instead")
                report_type = "10-K"
                if "10-K" not in entity_sub["form"].unique(): #If our firm released neither 10-Q nor a 10-K 
                    print("No 10-Q or 10-K for "+file+" skipping to next quarter")
                    continue
            num = numdict[file]
            #Get the meta data
            quaterly_report_adsh = entity_sub[entity_sub["form"]==report_type]["adsh"].iloc[0] #fetch report identifier "adsh"
            quaterly_report_period = entity_sub[entity_sub["form"]==report_type]["period"].iloc[0] #fetch report accounting period

            #Get the market data
            first_filing_date = datetime.strptime(entity_sub[entity_sub["form"]==report_type]["accepted"].iloc[0].replace(".0",""), "%Y-%m-%d %H:%M:%S") #fetch report acceptance date

            print("Fetching Report that was published in :  "+str(quaterly_report_period))

            #For the first date for which we have accounting data, download all the data we need for the CAPM 
            if ((date_list==[]) and (type(first_filing_date)==datetime)): #only do this once
                #Get the symbol for stock market API
                #Setting up dictionary
                regression_stats_dict = {"filing_date":None,
                                        "next_year_beta":None,
                                        "next_year_beta_tstat":None,
                                        "next_year_alpha":None,
                                        "next_year_alpha_tstat":None,
                                        "next_year_IR":None,
                                        "next_year_market_return":None,
                                        "next_year_equity_return":None,
                                        "last_year_start_date":None,
                                        "last_year_beta":None, 
                                        "last_year_beta_tstat":None,
                                        "last_year_alpha":None, 
                                        "last_year_alpha_tstat":None,
                                        "last_year_IR": None,
                                        "last_year_market_return":None,
                                        "last_year_equity_return":None,
                                        "last_year_vola":None, 
                                        "last_year_vola_explained_by_market":None}    


                #Getting stock prices and factors 
                start = first_filing_date-pd.Timedelta(52,"W")
                end = datetime.now()

                try:
                    share_price_ts = pdr.DataReader(str(firms_df[firms_df["CIK"]==CIK]["Ticker"].iloc[0]), "av-weekly-adjusted", start=start,end=end)["adjusted close"]
                except ValueError:
                    try:
                        share_price_ts = pdr.DataReader(str(firms_df[firms_df["CIK"]==CIK]["Ticker"].iloc[1]), "av-weekly-adjusted", start=start,end=end)["adjusted close"]
                    except ValueError:
                        print('No Stock Prices available')
                        #Get the accounting data 
                        entity_num_quarterly = num[num["adsh"] == quaterly_report_adsh] #fetch report
                        entity_num_quarterly_period = entity_num_quarterly[(entity_num_quarterly["ddate"]==quaterly_report_period)&
                                                                           entity_num_quarterly["qtrs"].isin([0,1])] #Only get the data for the last quarter
                        date_list.append(quaterly_report_period)
                        report_list.append(entity_num_quarterly_period)

                        if report_type == "10-K":
                            annual_report_list.append(entity_num_quarterly[(entity_num_quarterly["ddate"]==quaterly_report_period)&
                                                                            entity_num_quarterly["qtrs"].isin([0,4])])#Get last year data
                            annual_report_date_list.append(quaterly_report_period)
                            print("Also saving this as 10-K report")
                        print("################################################## Next Period#################################################")
                        continue

                return_equity = share_price_ts.pct_change()
                capm_df = pd.concat([return_equity,return_market,return_risk_free], axis=1).dropna()
                capm_df.columns = ["Equity Return", "Market Return", "Risk-Free Return"]
                capm_df["Risk_Premium_Beta"] = capm_df["Market Return"] - capm_df["Risk-Free Return"]         
                capm_df.index = pd.DatetimeIndex(capm_df.index)


                period_start = first_filing_date
                period_end = first_filing_date+pd.Timedelta(52,"W")
                #Next year Stock analysis:
            if len(capm_df[period_start:period_end])>26:
                reg_df = capm_df.loc[period_start:period_end]
                X = reg_df[["Risk-Free Return", "Risk_Premium_Beta"]]
                X = sm.add_constant(X)
                model = sm.OLS(endog = reg_df["Equity Return"], exog = X, missing = "drop")
                results = model.fit()
                information_ratio_capm = ((results.params["const"]+1)**12-1)/(results.resid.std()*np.sqrt(52))

                #Printing relevant data
                print("Equity Market Stats for 1Y since Filing on: "+str(first_filing_date))
                print(results.params)
                print("With T-Values:")
                print(results.tvalues)
                print("Information Ratio last year: "+str(information_ratio_capm))

                #Saving Data
                regression_stats_dict["filing_date"] = first_filing_date
                regression_stats_dict["next_year_beta"] = results.params["Risk_Premium_Beta"]
                regression_stats_dict["next_year_beta_tstat"] = results.tvalues["Risk_Premium_Beta"]
                regression_stats_dict["next_year_alpha"] = results.params["const"]
                regression_stats_dict["next_year_alpha_tstat"] = results.tvalues["const"]
                regression_stats_dict["next_year_IR"] = information_ratio_capm
                regression_stats_dict["next_year_market_return"] = (reg_df["Market Return"]+1).iloc[-1]-1
                regression_stats_dict["next_year_equity_return"] = (reg_df["Equity Return"]+1).iloc[-1]-1


                #Make dataframe and store it to list here already if we have not enough data for historic analysis
                if len(capm_df.loc[first_filing_date-pd.Timedelta(52,"w"):first_filing_date])< 26:
                    market_data_df = pd.DataFrame.from_dict(regression_stats_dict,orient='index')
                    market_data_df.columns = [quaterly_report_period]
                    market_data_list.append(market_data_df)

            #Historic Stock Return Analysis if we have 26 weeks of data (1/2 year)
            if len(capm_df.loc[first_filing_date-pd.Timedelta(52,"w"):first_filing_date])>= 26:
                #Setup and run regression
                period_start = first_filing_date-pd.Timedelta(52,"w")
                period_end = first_filing_date
                reg_df = capm_df.loc[period_start:period_end]
                X = reg_df[["Risk-Free Return", "Risk_Premium_Beta"]]
                X = sm.add_constant(X)
                model = sm.OLS(endog = reg_df["Equity Return"], exog = X, missing = "drop")
                results = model.fit()
                information_ratio_capm = ((results.params["const"]+1)**12-1)/(results.resid.std()*np.sqrt(52))

                #Printing relevant data
                print("1Y Historic Equity Market Stats (filing between): "+str(period_start)+" and "+str(period_end))
                print(results.params)
                print("With T-Values:")
                print(results.tvalues)
                print("Information Ratio next year:"+str(information_ratio_capm))

                #saving relevant data
                regression_stats_dict["last_year_start_date"] = reg_df.first_valid_index()
                regression_stats_dict["last_year_beta"] = results.params["Risk_Premium_Beta"]
                regression_stats_dict["last_year_beta_tstat"]= results.tvalues["Risk_Premium_Beta"]
                regression_stats_dict["last_year_alpha"]=results.params["const"]
                regression_stats_dict["last_year_alpha_tstat"]=results.tvalues["const"]
                regression_stats_dict["last_year_IR"] = information_ratio_capm
                regression_stats_dict["last_year_market_return"]=(reg_df["Market Return"]+1).iloc[-1]-1
                regression_stats_dict["last_year_equity_return"]=(reg_df["Equity Return"]+1).iloc[-1]-1
                regression_stats_dict["last_year_vola"]= reg_df["Equity Return"].std()*np.sqrt(len(reg_df))

                #Explaining Vola of Stock with Market: 
                X = reg_df["Equity Return"]
                X = sm.add_constant(X)
                model = sm.OLS(endog = reg_df["Risk_Premium_Beta"], exog = X , missing = "drop")
                results = model.fit()
                regression_stats_dict["last_year_vola_explained_by_market"]=results.params["Equity Return"]

                #Make dataframe and store it to list
                market_data_df = pd.DataFrame.from_dict(regression_stats_dict,orient='index')
                market_data_df.columns = [quaterly_report_period]
                market_data_list.append(market_data_df)

            #Get the accounting data 
            entity_num_quarterly = num[num["adsh"] == quaterly_report_adsh] #fetch report
            entity_num_quarterly_period = entity_num_quarterly[(entity_num_quarterly["ddate"]==quaterly_report_period)&
                                                               entity_num_quarterly["qtrs"].isin([0,1])] #Only get the data for the last quarter
            date_list.append(quaterly_report_period)
            report_list.append(entity_num_quarterly_period)



            if report_type == "10-K":
                annual_report_list.append(entity_num_quarterly[(entity_num_quarterly["ddate"]==quaterly_report_period)&
                                                                entity_num_quarterly["qtrs"].isin([0,4])])#Get last year data
                annual_report_date_list.append(quaterly_report_period)
                print("Also saving this as 10-K report")

            print("################################################## Next Period#################################################")

        if len(annual_report_list)>1:
            annual_report_long = pd.concat(annual_report_list)
            annual_reports_complete_long = pd.pivot_table(annual_report_long, index= "ddate",columns = "tag", values="value")
        if len(market_data_list)>1:
            market_data_results_wide = pd.concat(market_data_list,axis=1)
            market_data_results_long = market_data_results_wide.transpose()
            complete_data_long = pd.merge(annual_reports_complete_long,market_data_results_long, left_index=True, right_index=True)
            complete_data_long.index = pd.DatetimeIndex(complete_data_long.index)
            complete_data_long.index.name = str(name)+"_"+str(entity_sub["sic"].iloc[0])

            complete_data_long.transpose().to_csv("Output/Sectors/"+sector_name+"/"+str(name).replace("/","_")+"_complete.csv")


        elapsed_time = time.process_time() - t
        print("Processing Time in Minutes: "+str(elapsed_time/60))
        print(str(name)+" Done")
        print("IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII")
        time.sleep(12)

    print("Total Time needed for "+sector_name+": "+str(time.process_time()- time_long))

    
all_time = time.process_time()- time_all
print("Full time needed in minutes: "+str(all_time/60))
# Out:
# *********************************************************************************************************************
# starting with: PATENT OWNERS & LESSORS
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# Starting with: STELLA BLU, INC
# STELLA BLU, INC not in 2009q1
# STELLA BLU, INC not in 2009q2
# STELLA BLU, INC not in 2009q3
# STELLA BLU, INC not in 2009q4
# STELLA BLU, INC not in 2010q1
# STELLA BLU, INC not in 2010q2
# STELLA BLU, INC not in 2010q3
# STELLA BLU, INC not in 2010q4
# STELLA BLU, INC not in 2011q1
# STELLA BLU, INC not in 2011q2
# STELLA BLU, INC not in 2011q3
# STELLA BLU, INC not in 2011q4
# STELLA BLU, INC not in 2012q1
# STELLA BLU, INC not in 2012q2
# STELLA BLU, INC not in 2012q3
# STELLA BLU, INC not in 2012q4
# STELLA BLU, INC not in 2013q1
# STELLA BLU, INC not in 2013q2
# STELLA BLU, INC not in 2013q3
# STELLA BLU, INC not in 2013q4
# Report that was published in: 2014q1
#         form    fy  fp   fye    period                  adsh  \
# 202   10-Q/A  2013  Q3  1231  20130930  0001144204-14-001958
# 5020    10-K  2013  FY  1231  20131231  0001144204-14-015642
#
#                    accepted
# 202   2014-01-13 17:11:00.0
# 5020  2014-03-14 10:05:00.0
# No 10-Q in 2014q1, fetching 10-K instead
# Fetching Report that was published in :  20131231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2014q2
#       form    fy  fp   fye    period                  adsh  \
# 2588  10-Q  2014  Q1  1231  20140331  0001144204-14-027399
#
#                    accepted
# 2588  2014-05-05 07:40:00.0
# Fetching Report that was published in :  20140331
# ################################################## Next Period#################################################
# Report that was published in: 2014q3
#       form    fy  fp   fye    period                  adsh  \
# 4423  10-Q  2014  Q2  1231  20140630  0001144204-14-048781
#
#                    accepted
# 4423  2014-08-12 12:12:00.0
# Fetching Report that was published in :  20140630
# ################################################## Next Period#################################################
# Report that was published in: 2014q4
#       form    fy  fp   fye    period                  adsh  \
# 4308  10-Q  2014  Q3  1231  20140930  0001144204-14-066899
#
#                    accepted
# 4308  2014-11-12 09:54:00.0
# Fetching Report that was published in :  20140930
# ################################################## Next Period#################################################
# Report that was published in: 2015q1
#       form    fy  fp   fye    period                  adsh  \
# 6156  10-K  2014  FY  1231  20141231  0001517126-15-000065
#
#                    accepted
# 6156  2015-03-27 16:04:00.0
# No 10-Q in 2015q1, fetching 10-K instead
# Fetching Report that was published in :  20141231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2015q2
#       form    fy  fp   fye    period                  adsh  \
# 7017  10-Q  2015  Q1  1231  20150331  0001517126-15-000139
#
#                    accepted
# 7017  2015-05-20 16:16:00.0
# Fetching Report that was published in :  20150331
# ################################################## Next Period#################################################
# Report that was published in: 2015q3
#       form    fy  fp   fye    period                  adsh  \
# 5789  10-Q  2015  Q2  1231  20150630  0001517126-15-000196
#
#                    accepted
# 5789  2015-08-14 15:09:00.0
# Fetching Report that was published in :  20150630
# ################################################## Next Period#################################################
# Report that was published in: 2015q4
#         form    fy  fp   fye    period                  adsh  \
# 6859  10-Q/A  2015  Q3  1231  20150930  0001517126-15-000263
#
#                    accepted
# 6859  2015-12-14 16:20:00.0
# No 10-Q in 2015q4, fetching 10-K instead
# No 10-Q or 10-K for 2015q4 skipping to next quarter
# STELLA BLU, INC not in 2016q1
# Report that was published in: 2016q2
#      form    fy  fp   fye    period                  adsh  \
# 589  10-K  2015  FY  1231  20151231  0001517126-16-000317
#
#                   accepted
# 589  2016-04-14 16:11:00.0
# No 10-Q in 2016q2, fetching 10-K instead
# Fetching Report that was published in :  20151231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# STELLA BLU, INC not in 2016q3
# STELLA BLU, INC not in 2016q4
# STELLA BLU, INC not in 2017q1
# STELLA BLU, INC not in 2017q2
# STELLA BLU, INC not in 2017q3
# STELLA BLU, INC not in 2017q4
# STELLA BLU, INC not in 2018q1
# STELLA BLU, INC not in 2018q2
# STELLA BLU, INC not in 2018q3
# STELLA BLU, INC not in 2018q4
# STELLA BLU, INC not in 2019q1
# STELLA BLU, INC not in 2019q2
# STELLA BLU, INC not in 2019q3
# STELLA BLU, INC not in 2019q4
# STELLA BLU, INC not in 2020q1
# STELLA BLU, INC not in 2020q2
# STELLA BLU, INC not in 2020q3
# STELLA BLU, INC not in 2020q4
# STELLA BLU, INC not in 2021q1
# Processing Time in Minutes: 0.020572916666666666
# STELLA BLU, INC Done
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# Starting with: VRINGO INC
# VRINGO INC not in 2009q1
# VRINGO INC not in 2009q2
# VRINGO INC not in 2009q3
# VRINGO INC not in 2009q4
# VRINGO INC not in 2010q1
# VRINGO INC not in 2010q2
# VRINGO INC not in 2010q3
# VRINGO INC not in 2010q4
# VRINGO INC not in 2011q1
# VRINGO INC not in 2011q2
# Report that was published in: 2011q3
#         form    fy  fp   fye    period                  adsh  \
# 6112  10-Q/A  2011  Q2  1231  20110630  0001144204-11-051577
#
#                    accepted
# 6112  2011-09-07 15:30:00.0
# No 10-Q in 2011q3, fetching 10-K instead
# No 10-Q or 10-K for 2011q3 skipping to next quarter
# Report that was published in: 2011q4
#       form    fy  fp   fye    period                  adsh  \
# 5073  10-Q  2011  Q3  1231  20110930  0001144204-11-063796
#
#                    accepted
# 5073  2011-11-14 11:57:00.0
# Fetching Report that was published in :  20110930
# ################################################## Next Period#################################################
# Report that was published in: 2012q1
#      form    fy  fp   fye    period                  adsh  \
# 260  10-K  2011  FY  1231  20111231  0001144204-12-018817
#
#                   accepted
# 260  2012-03-30 16:07:00.0
# No 10-Q in 2012q1, fetching 10-K instead
# Fetching Report that was published in :  20111231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2012q2
#       form    fy   fp   fye    period                  adsh  \
# 198    S-4   NaN  NaN   NaN  20111231  0001144204-12-020499
# 6633  10-Q  2012   Q1  1231  20120331  0001144204-12-029638
#
#                    accepted
# 198   2012-04-06 11:29:00.0
# 6633  2012-05-15 16:37:00.0
# Fetching Report that was published in :  20120331
# ################################################## Next Period#################################################
# Report that was published in: 2012q3
#       form    fy  fp   fye    period                  adsh  \
# 5050  10-Q  2012  Q2  1231  20120630  0001144204-12-045744
#
#                    accepted
# 5050  2012-08-14 16:28:00.0
# Fetching Report that was published in :  20120630
# ################################################## Next Period#################################################
# Report that was published in: 2012q4
#       form    fy  fp   fye    period                  adsh  \
# 5459  10-Q  2012  Q3  1231  20120930  0001144204-12-062505
#
#                    accepted
# 5459  2012-11-14 16:07:00.0
# Fetching Report that was published in :  20120930
# ################################################## Next Period#################################################
# Report that was published in: 2013q1
#       form    fy  fp   fye    period                  adsh  \
# 5770  10-K  2012  FY  1231  20121231  0001144204-13-016671
#
#                    accepted
# 5770  2013-03-21 16:04:00.0
# No 10-Q in 2013q1, fetching 10-K instead
# Fetching Report that was published in :  20121231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2013q2
#       form    fy  fp   fye    period                  adsh  \
# 4470  10-Q  2013  Q1  1231  20130331  0001144204-13-027414
#
#                    accepted
# 4470  2013-05-09 16:08:00.0
# Fetching Report that was published in :  20130331
# ################################################## Next Period#################################################
# Report that was published in: 2013q3
#       form    fy  fp   fye    period                  adsh  \
# 3264  10-Q  2013  Q2  1231  20130630  0001144204-13-043978
#
#                    accepted
# 3264  2013-08-08 16:16:00.0
# Fetching Report that was published in :  20130630
# ################################################## Next Period#################################################
# Report that was published in: 2013q4
#       form    fy  fp   fye    period                  adsh  \
# 2822  10-Q  2013  Q3  1231  20130930  0001144204-13-059609
#
#                    accepted
# 2822  2013-11-07 16:09:00.0
# Fetching Report that was published in :  20130930
# ################################################## Next Period#################################################
# Report that was published in: 2014q1
#       form    fy  fp   fye    period                  adsh  \
# 4409  10-K  2013  FY  1231  20131231  0001144204-14-014529
#
#                    accepted
# 4409  2014-03-10 16:26:00.0
# No 10-Q in 2014q1, fetching 10-K instead
# Fetching Report that was published in :  20131231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2014q2
#       form    fy  fp   fye    period                  adsh  \
# 3601  10-Q  2014  Q1  1231  20140331  0001144204-14-028600
#
#                    accepted
# 3601  2014-05-08 16:01:00.0
# Fetching Report that was published in :  20140331
# ################################################## Next Period#################################################
# Report that was published in: 2014q3
#       form    fy  fp   fye    period                  adsh  \
# 2391  10-Q  2014  Q2  1231  20140630  0001144204-14-047373
#
#                    accepted
# 2391  2014-08-06 16:11:00.0
# Fetching Report that was published in :  20140630
# ################################################## Next Period#################################################
# Report that was published in: 2014q4
#       form    fy  fp   fye    period                  adsh  \
# 1899  10-Q  2014  Q3  1231  20140930  0001144204-14-064960
#
#                    accepted
# 1899  2014-11-04 16:15:00.0
# Fetching Report that was published in :  20140930
# ################################################## Next Period#################################################
# Report that was published in: 2015q1
#       form    fy  fp   fye    period                  adsh  \
# 5110  10-K  2014  FY  1231  20141231  0001144204-15-016329
#
#                    accepted
# 5110  2015-03-16 16:10:00.0
# No 10-Q in 2015q1, fetching 10-K instead
# Fetching Report that was published in :  20141231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2015q2
#       form    fy  fp   fye    period                  adsh  \
# 2451  10-Q  2015  Q1  1231  20150331  0001144204-15-027616
#
#                    accepted
# 2451  2015-05-05 16:11:00.0
# Fetching Report that was published in :  20150331
# ################################################## Next Period#################################################
# Report that was published in: 2015q3
#       form    fy  fp   fye    period                  adsh  \
# 1805  10-Q  2015  Q2  1231  20150630  0001144204-15-046130
#
#                    accepted
# 1805  2015-08-04 16:09:00.0
# Fetching Report that was published in :  20150630
# ################################################## Next Period#################################################
# Report that was published in: 2015q4
#       form    fy  fp   fye    period                  adsh  \
# 3590  10-Q  2015  Q3  1231  20150930  0001144204-15-063762
#
#                    accepted
# 3590  2015-11-09 16:17:00.0
# Fetching Report that was published in :  20150930
# ################################################## Next Period#################################################
# Report that was published in: 2016q1
#       form    fy  fp   fye    period                  adsh  \
# 4249  10-K  2015  FY  1231  20151231  0001144204-16-087235
#
#                    accepted
# 4249  2016-03-10 16:32:00.0
# No 10-Q in 2016q1, fetching 10-K instead
# Fetching Report that was published in :  20151231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2016q2
#       form    fy  fp   fye    period                  adsh  \
# 2595  10-Q  2016  Q1  1231  20160331  0001144204-16-099238
#
#                    accepted
# 2595  2016-05-05 16:08:00.0
# Fetching Report that was published in :  20160331
# ################################################## Next Period#################################################
# Report that was published in: 2016q3
#       form    fy   fp   fye    period                  adsh  \
# 4924  10-Q  2016   Q2  1231  20160630  0001144204-16-119382
# 6339   S-4   NaN  NaN  1231  20160630  0001144204-16-123406
#
#                    accepted
# 4924  2016-08-15 16:03:00.0
# 6339  2016-09-09 16:08:00.0
# Fetching Report that was published in :  20160630
# ################################################## Next Period#################################################
# Report that was published in: 2016q4
#        form    fy   fp   fye    period                  adsh  \
# 597   S-4/A   NaN  NaN  1231  20160630  0001144204-16-129474
# 3481   10-Q  2016   Q3  1231  20160930  0001144204-16-132791
#
#                    accepted
# 597   2016-10-25 21:45:00.0
# 3481  2016-11-09 16:08:00.0
# Fetching Report that was published in :  20160930
# ################################################## Next Period#################################################
# Report that was published in: 2017q1
#       form    fy  fp   fye    period                  adsh  \
# 5766  10-K  2016  FY  1231  20161231  0001144204-17-017688
#
#                    accepted
# 5766  2017-03-30 16:12:00.0
# No 10-Q in 2017q1, fetching 10-K instead
# Fetching Report that was published in :  20161231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2017q2
#       form    fy  fp   fye    period                  adsh  \
# 5272  10-Q  2017  Q1  1231  20170331  0001144204-17-027519
#
#                    accepted
# 5272  2017-05-15 16:29:00.0
# Fetching Report that was published in :  20170331
# ################################################## Next Period#################################################
# Report that was published in: 2017q3
#       form    fy  fp   fye    period                  adsh  \
# 3369  10-Q  2017  Q2  1231  20170630  0001144204-17-041654
#
#                    accepted
# 3369  2017-08-09 16:04:00.0
# Fetching Report that was published in :  20170630
# ################################################## Next Period#################################################
# Report that was published in: 2017q4
#       form    fy  fp   fye    period                  adsh  \
# 3538  10-Q  2017  Q3  1231  20170930  0001144204-17-057715
#
#                    accepted
# 3538  2017-11-09 16:05:00.0
# Fetching Report that was published in :  20170930
# ################################################## Next Period#################################################
# Report that was published in: 2018q1
#       form    fy  fp   fye    period                  adsh  \
# 5665  10-K  2017  FY  1231  20171231  0001144204-18-017944
#
#                    accepted
# 5665  2018-03-29 16:13:00.0
# No 10-Q in 2018q1, fetching 10-K instead
# Fetching Report that was published in :  20171231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2018q2
#       form    fy  fp   fye    period                  adsh  \
# 5598  10-Q  2018  Q1  1231  20180331  0001144204-18-028911
#
#                    accepted
# 5598  2018-05-15 16:23:00.0
# Fetching Report that was published in :  20180331
# ################################################## Next Period#################################################
# Report that was published in: 2018q3
#       form    fy  fp   fye    period                  adsh  \
# 4648  10-Q  2018  Q2  1231  20180630  0001144204-18-044767
#
#                    accepted
# 4648  2018-08-14 17:29:00.0
# Fetching Report that was published in :  20180630
# 1Y Historic Equity Market Stats (filing between): 2017-08-15 17:29:00 and 2018-08-14 17:29:00
# const                -0.048058
# Risk-Free Return    -25.816209
# Risk_Premium_Beta     0.271422
# dtype: float64
# With T-Values:
# const               -2.101477
# Risk-Free Return    -0.878601
# Risk_Premium_Beta    0.228369
# dtype: float64
# Information Ratio next year:-0.5208070291831337
# ################################################## Next Period#################################################
# Report that was published in: 2018q4
#       form    fy  fp   fye    period                  adsh  \
# 4640  10-Q  2018  Q3  1231  20180930  0001144204-18-060039
#
#                    accepted
# 4640  2018-11-14 17:23:00.0
# Fetching Report that was published in :  20180930
# Equity Market Stats for 1Y since Filing on: 2018-11-14 17:23:00
# const                -0.048058
# Risk-Free Return    -25.816209
# Risk_Premium_Beta     0.271422
# dtype: float64
# With T-Values:
# const               -2.101477
# Risk-Free Return    -0.878601
# Risk_Premium_Beta    0.228369
# dtype: float64
# Information Ratio last year: -0.5208070291831337
# 1Y Historic Equity Market Stats (filing between): 2017-11-15 17:23:00 and 2018-11-14 17:23:00
# const                -0.036807
# Risk-Free Return    -11.679409
# Risk_Premium_Beta    -0.087807
# dtype: float64
# With T-Values:
# const               -1.949900
# Risk-Free Return    -0.467197
# Risk_Premium_Beta   -0.085461
# dtype: float64
# Information Ratio next year:-0.41974743101945916
# ################################################## Next Period#################################################
# VRINGO INC not in 2019q1
# Report that was published in: 2019q2
#       form    fy  fp   fye    period                  adsh  \
# 65    10-K  2018  FY  1231  20181231  0001144204-19-017496
# 5587  10-Q  2019  Q1  1231  20190331  0001144204-19-026665
#
#                    accepted
# 65    2019-04-01 17:20:00.0
# 5587  2019-05-15 17:23:00.0
# Fetching Report that was published in :  20190331
# Equity Market Stats for 1Y since Filing on: 2019-05-15 17:23:00
# const                -0.036807
# Risk-Free Return    -11.679409
# Risk_Premium_Beta    -0.087807
# dtype: float64
# With T-Values:
# const               -1.949900
# Risk-Free Return    -0.467197
# Risk_Premium_Beta   -0.085461
# dtype: float64
# Information Ratio last year: -0.41974743101945916
# 1Y Historic Equity Market Stats (filing between): 2018-05-16 17:23:00 and 2019-05-15 17:23:00
# const               -0.022662
# Risk-Free Return     0.787395
# Risk_Premium_Beta    1.444227
# dtype: float64
# With T-Values:
# const               -1.069355
# Risk-Free Return     0.042846
# Risk_Premium_Beta    1.607729
# dtype: float64
# Information Ratio next year:-0.26238836288275885
# ################################################## Next Period#################################################
# Report that was published in: 2019q3
#       form    fy  fp   fye    period                  adsh  \
# 5577  10-Q  2019  Q2  1231  20190630  0001144204-19-040130
#
#                    accepted
# 5577  2019-08-14 17:04:00.0
# Fetching Report that was published in :  20190630
# Equity Market Stats for 1Y since Filing on: 2019-08-14 17:04:00
# const               -0.022662
# Risk-Free Return     0.787395
# Risk_Premium_Beta    1.444227
# dtype: float64
# With T-Values:
# const               -1.069355
# Risk-Free Return     0.042846
# Risk_Premium_Beta    1.607729
# dtype: float64
# Information Ratio last year: -0.26238836288275885
# 1Y Historic Equity Market Stats (filing between): 2018-08-15 17:04:00 and 2019-08-14 17:04:00
# const               -0.024314
# Risk-Free Return     8.947219
# Risk_Premium_Beta    1.301128
# dtype: float64
# With T-Values:
# const               -1.238975
# Risk-Free Return     0.620213
# Risk_Premium_Beta    1.726484
# dtype: float64
# Information Ratio next year:-0.3107461149453399
# ################################################## Next Period#################################################
# Report that was published in: 2019q4
#       form    fy  fp   fye    period                  adsh  \
# 8436  10-Q  2019  Q3  1231  20190930  0001104659-19-064328
#
#                    accepted
# 8436  2019-11-14 17:07:00.0
# Fetching Report that was published in :  20190930
# Equity Market Stats for 1Y since Filing on: 2019-11-14 17:07:00
# const               -0.024314
# Risk-Free Return     8.947219
# Risk_Premium_Beta    1.301128
# dtype: float64
# With T-Values:
# const               -1.238975
# Risk-Free Return     0.620213
# Risk_Premium_Beta    1.726484
# dtype: float64
# Information Ratio last year: -0.3107461149453399
# 1Y Historic Equity Market Stats (filing between): 2018-11-15 17:07:00 and 2019-11-14 17:07:00
# const               -0.024317
# Risk-Free Return     8.123847
# Risk_Premium_Beta    1.943792
# dtype: float64
# With T-Values:
# const               -1.372464
# Risk-Free Return     0.797299
# Risk_Premium_Beta    2.583012
# dtype: float64
# Information Ratio next year:-0.3263005869065898
# ################################################## Next Period#################################################
# VRINGO INC not in 2020q1
# Report that was published in: 2020q2
#       form    fy  fp   fye    period                  adsh  \
# 1992  10-K  2019  FY  1231  20191231  0001104659-20-048780
#
#                    accepted
# 1992  2020-04-20 17:24:00.0
# No 10-Q in 2020q2, fetching 10-K instead
# Fetching Report that was published in :  20191231
# Equity Market Stats for 1Y since Filing on: 2020-04-20 17:24:00
# const               -0.024317
# Risk-Free Return     8.123847
# Risk_Premium_Beta    1.943792
# dtype: float64
# With T-Values:
# const               -1.372464
# Risk-Free Return     0.797299
# Risk_Premium_Beta    2.583012
# dtype: float64
# Information Ratio last year: -0.3263005869065898
# 1Y Historic Equity Market Stats (filing between): 2019-04-22 17:24:00 and 2020-04-20 17:24:00
# const               -0.005701
# Risk-Free Return    -8.357278
# Risk_Premium_Beta    2.271926
# dtype: float64
# With T-Values:
# const               -0.216196
# Risk-Free Return    -0.676973
# Risk_Premium_Beta    3.702612
# dtype: float64
# Information Ratio next year:-0.055805472993569874
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2020q3
#        form    fy  fp   fye    period                  adsh  \
# 422    10-Q  2020  Q1  1231  20200331  0001558370-20-008024
# 10609  10-Q  2020  Q2  1231  20200630  0001558370-20-010752
#
#                     accepted
# 422    2020-07-06 16:56:00.0
# 10609  2020-08-19 17:07:00.0
# Fetching Report that was published in :  20200331
# Equity Market Stats for 1Y since Filing on: 2020-07-06 16:56:00
# const               -0.005701
# Risk-Free Return    -8.357278
# Risk_Premium_Beta    2.271926
# dtype: float64
# With T-Values:
# const               -0.216196
# Risk-Free Return    -0.676973
# Risk_Premium_Beta    3.702612
# dtype: float64
# Information Ratio last year: -0.055805472993569874
# 1Y Historic Equity Market Stats (filing between): 2019-07-08 16:56:00 and 2020-07-06 16:56:00
# const                 0.053046
# Risk-Free Return    -23.390791
# Risk_Premium_Beta     3.222306
# dtype: float64
# With T-Values:
# const                1.089518
# Risk-Free Return    -0.954645
# Risk_Premium_Beta    2.881041
# dtype: float64
# Information Ratio next year:0.37977920607374904
# ################################################## Next Period#################################################
# Report that was published in: 2020q4
#        form    fy  fp   fye    period                  adsh  \
# 11111  10-Q  2020  Q3  1231  20200930  0001558370-20-013896
#
#                     accepted
# 11111  2020-11-16 16:49:00.0
# Fetching Report that was published in :  20200930
# Equity Market Stats for 1Y since Filing on: 2020-11-16 16:49:00
# const                 0.053046
# Risk-Free Return    -23.390791
# Risk_Premium_Beta     3.222306
# dtype: float64
# With T-Values:
# const                1.089518
# Risk-Free Return    -0.954645
# Risk_Premium_Beta    2.881041
# dtype: float64
# Information Ratio last year: 0.37977920607374904
# 1Y Historic Equity Market Stats (filing between): 2019-11-18 16:49:00 and 2020-11-16 16:49:00
# const                 0.049442
# Risk-Free Return    -41.622249
# Risk_Premium_Beta     2.709517
# dtype: float64
# With T-Values:
# const                0.988222
# Risk-Free Return    -1.311070
# Risk_Premium_Beta    2.461861
# dtype: float64
# Information Ratio next year:0.3383946353057253
# ################################################## Next Period#################################################
# Report that was published in: 2021q1
#        form    fy  fp   fye    period                  adsh  \
# 17232  10-K  2020  FY  1231  20201231  0001558370-21-003840
#
#                     accepted
# 17232  2021-03-31 17:05:00.0
# No 10-Q in 2021q1, fetching 10-K instead
# Fetching Report that was published in :  20201231
# Equity Market Stats for 1Y since Filing on: 2021-03-31 17:05:00
# const                 0.049442
# Risk-Free Return    -41.622249
# Risk_Premium_Beta     2.709517
# dtype: float64
# With T-Values:
# const                0.988222
# Risk-Free Return    -1.311070
# Risk_Premium_Beta    2.461861
# dtype: float64
# Information Ratio last year: 0.3383946353057253
# 1Y Historic Equity Market Stats (filing between): 2020-04-01 17:05:00 and 2021-03-31 17:05:00
# const                  0.043417
# Risk-Free Return    -280.286392
# Risk_Premium_Beta      2.661627
# dtype: float64
# With T-Values:
# const                0.924985
# Risk-Free Return    -2.366301
# Risk_Premium_Beta    1.844832
# dtype: float64
# Information Ratio next year:0.30001104958034497
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Processing Time in Minutes: 0.0828125
# VRINGO INC Done
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# Starting with: ALL MARKETING SOLUTIONS, INC.
# ALL MARKETING SOLUTIONS, INC. not in 2009q1
# ALL MARKETING SOLUTIONS, INC. not in 2009q2
# ALL MARKETING SOLUTIONS, INC. not in 2009q3
# ALL MARKETING SOLUTIONS, INC. not in 2009q4
# ALL MARKETING SOLUTIONS, INC. not in 2010q1
# ALL MARKETING SOLUTIONS, INC. not in 2010q2
# ALL MARKETING SOLUTIONS, INC. not in 2010q3
# ALL MARKETING SOLUTIONS, INC. not in 2010q4
# ALL MARKETING SOLUTIONS, INC. not in 2011q1
# ALL MARKETING SOLUTIONS, INC. not in 2011q2
# ALL MARKETING SOLUTIONS, INC. not in 2011q3
# ALL MARKETING SOLUTIONS, INC. not in 2011q4
# Report that was published in: 2012q1
#      form    fy  fp   fye    period                  adsh  \
# 757  10-K  2011  FY  1231  20111231  0001494733-12-000052
#
#                   accepted
# 757  2012-03-30 12:23:00.0
# No 10-Q in 2012q1, fetching 10-K instead
# Fetching Report that was published in :  20111231
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2012q2
#         form    fy  fp   fye    period                  adsh  \
# 52    10-K/A  2011  FY  1231  20111231  0001494733-12-000056
# 6062    10-Q  2012  Q1  1231  20120331  0001494733-12-000082
#
#                    accepted
# 52    2012-03-30 18:58:00.0
# 6062  2012-05-14 11:30:00.0
# Fetching Report that was published in :  20120331
# ################################################## Next Period#################################################
# Report that was published in: 2012q3
#         form    fy  fp   fye    period                  adsh  \
# 6500  10-Q/A  2012  Q2  1231  20120630  0001494733-12-000194
#
#                    accepted
# 6500  2012-08-30 14:13:00.0
# No 10-Q in 2012q3, fetching 10-K instead
# No 10-Q or 10-K for 2012q3 skipping to next quarter
# Report that was published in: 2012q4
#       form    fy  fp   fye    period                  adsh  \
# 6050  10-Q  2012  Q3  1231  20120930  0001494733-12-000255
#
#                    accepted
# 6050  2012-11-14 15:23:00.0
# Fetching Report that was published in :  20120930
# ################################################## Next Period#################################################
# ALL MARKETING SOLUTIONS, INC. not in 2013q1
# Report that was published in: 2013q2
#       form    fy  fp   fye    period                  adsh  \
# 431   10-K  2012  FY  1231  20121231  0001494733-13-000068
# 7406  10-Q  2013  Q1  1231  20130331  0001494733-13-000113
#
#                    accepted
# 431   2013-04-01 16:44:00.0
# 7406  2013-05-16 12:27:00.0
# Fetching Report that was published in :  20130331
# ################################################## Next Period#################################################
# Report that was published in: 2013q3
#       form    fy  fp   fye    period                  adsh  \
# 5998  10-Q  2013  Q2  1231  20130630  0001494733-13-000163
#
#                    accepted
# 5998  2013-08-13 18:38:00.0
# Fetching Report that was published in :  20130630
# ################################################## Next Period#################################################
# Report that was published in: 2013q4
#       form    fy  fp   fye    period                  adsh  \
# 4477  10-Q  2013  Q3  1231  20130930  0001494733-13-000178
#
#                    accepted
# 4477  2013-11-12 15:51:00.0
# Fetching Report that was published in :  20130930
# ################################################## Next Period#################################################
# ALL MARKETING SOLUTIONS, INC. not in 2014q1
# Report that was published in: 2014q2
#         form    fy  fp   fye    period                  adsh  \
# 116   10-K/A  2013  FY  1231  20131231  0001494733-14-000010
# 7317  10-Q/A  2014  Q1  1231  20140331  0001494733-14-000018
#
#                    accepted
# 116   2014-04-02 18:22:00.0
# 7317  2014-05-21 15:52:00.0
# No 10-Q in 2014q2, fetching 10-K instead
# No 10-Q or 10-K for 2014q2 skipping to next quarter
# Report that was published in: 2014q3
#       form    fy  fp   fye    period                  adsh  \
# 6456  10-Q  2014  Q2  1231  20140630  0001494733-14-000024
#
#                    accepted
# 6456  2014-08-19 12:58:00.0
# Fetching Report that was published in :  20140630
# 1Y Historic Equity Market Stats (filing between): 2013-08-20 12:58:00 and 2014-08-19 12:58:00
# const                 0.015016
# Risk-Free Return     14.150155
# Risk_Premium_Beta    -0.150209
# dtype: float64
# With T-Values:
# const                0.746787
# Risk-Free Return     0.395951
# Risk_Premium_Beta   -0.087732
# dtype: float64
# Information Ratio next year:0.2404300075988187
# ################################################## Next Period#################################################
# Report that was published in: 2014q4
#       form    fy  fp   fye    period                  adsh  \
# 5931  10-Q  2014  Q3  1231  20140930  0001494733-14-000035
#
#                    accepted
# 5931  2014-11-14 08:28:00.0
# Fetching Report that was published in :  20140930
# Equity Market Stats for 1Y since Filing on: 2014-11-14 08:28:00
# const                 0.015016
# Risk-Free Return     14.150155
# Risk_Premium_Beta    -0.150209
# dtype: float64
# With T-Values:
# const                0.746787
# Risk-Free Return     0.395951
# Risk_Premium_Beta   -0.087732
# dtype: float64
# Information Ratio last year: 0.2404300075988187
# 1Y Historic Equity Market Stats (filing between): 2013-11-15 08:28:00 and 2014-11-14 08:28:00
# const                0.011294
# Risk-Free Return    -4.209517
# Risk_Premium_Beta   -1.371312
# dtype: float64
# With T-Values:
# const                0.549117
# Risk-Free Return    -0.137008
# Risk_Premium_Beta   -0.841260
# dtype: float64
# Information Ratio next year:0.14830388112828402
# ################################################## Next Period#################################################
# ALL MARKETING SOLUTIONS, INC. not in 2015q1
# Report that was published in: 2015q2
#       form    fy  fp   fye    period                  adsh  \
# 835   10-K  2014  FY  1231  20141231  0001494733-15-000062
# 6692  10-Q  2015  Q1  1231  20150331  0001494733-15-000080
#
#                    accepted
# 835   2015-04-15 18:56:00.0
# 6692  2015-05-15 18:29:00.0
# Fetching Report that was published in :  20150331
# Equity Market Stats for 1Y since Filing on: 2015-05-15 18:29:00
# const                0.011294
# Risk-Free Return    -4.209517
# Risk_Premium_Beta   -1.371312
# dtype: float64
# With T-Values:
# const                0.549117
# Risk-Free Return    -0.137008
# Risk_Premium_Beta   -0.841260
# dtype: float64
# Information Ratio last year: 0.14830388112828402
# 1Y Historic Equity Market Stats (filing between): 2014-05-16 18:29:00 and 2015-05-15 18:29:00
# const                 0.004664
# Risk-Free Return    -58.170107
# Risk_Premium_Beta    -3.964441
# dtype: float64
# With T-Values:
# const                0.147955
# Risk-Free Return    -1.865322
# Risk_Premium_Beta   -1.779790
# dtype: float64
# Information Ratio next year:0.0374970515843098
# ################################################## Next Period#################################################
# ALL MARKETING SOLUTIONS, INC. not in 2015q3
# ALL MARKETING SOLUTIONS, INC. not in 2015q4
# ALL MARKETING SOLUTIONS, INC. not in 2016q1
# ALL MARKETING SOLUTIONS, INC. not in 2016q2
# ALL MARKETING SOLUTIONS, INC. not in 2016q3
# Report that was published in: 2016q4
#       form    fy  fp   fye    period                  adsh  \
# 5974  10-Q  2015  Q2  1231  20150630  0001494733-16-000180
# 6173  10-Q  2015  Q3  1231  20150930  0001494733-16-000182
#
#                    accepted
# 5974  2016-11-29 11:48:00.0
# 6173  2016-12-07 11:37:00.0
# Fetching Report that was published in :  20150630
# Equity Market Stats for 1Y since Filing on: 2016-11-29 11:48:00
# const                 0.004664
# Risk-Free Return    -58.170107
# Risk_Premium_Beta    -3.964441
# dtype: float64
# With T-Values:
# const                0.147955
# Risk-Free Return    -1.865322
# Risk_Premium_Beta   -1.779790
# dtype: float64
# Information Ratio last year: 0.0374970515843098
# 1Y Historic Equity Market Stats (filing between): 2015-12-01 11:48:00 and 2016-11-29 11:48:00
# const                0.008965
# Risk-Free Return     9.387722
# Risk_Premium_Beta   -0.715680
# dtype: float64
# With T-Values:
# const                0.209552
# Risk-Free Return     0.260353
# Risk_Premium_Beta   -0.295223
# dtype: float64
# Information Ratio next year:0.052446654785190984
# ################################################## Next Period#################################################
# Report that was published in: 2017q1
#       form    fy  fp   fye    period                  adsh  \
# 1291  10-K  2015  FY  1231  20151231  0001494733-17-000008
# 5212  10-Q  2016  Q2  1231  20160630  0001494733-17-000027
# 5465  10-Q  2016  Q3  1231  20160930  0001494733-17-000030
#
#                    accepted
# 1291  2017-02-13 15:01:00.0
# 5212  2017-03-22 15:04:00.0
# 5465  2017-03-27 14:08:00.0
# Fetching Report that was published in :  20160630
# Equity Market Stats for 1Y since Filing on: 2017-03-22 15:04:00
# const                0.008965
# Risk-Free Return     9.387722
# Risk_Premium_Beta   -0.715680
# dtype: float64
# With T-Values:
# const                0.209552
# Risk-Free Return     0.260353
# Risk_Premium_Beta   -0.295223
# dtype: float64
# Information Ratio last year: 0.052446654785190984
# 1Y Historic Equity Market Stats (filing between): 2016-03-23 15:04:00 and 2017-03-22 15:04:00
# const                 0.029475
# Risk-Free Return     48.819647
# Risk_Premium_Beta     3.965284
# dtype: float64
# With T-Values:
# const                0.553766
# Risk-Free Return     1.144638
# Risk_Premium_Beta    0.995137
# dtype: float64
# Information Ratio next year:0.15970237249022648
# ################################################## Next Period#################################################
# ALL MARKETING SOLUTIONS, INC. not in 2017q2
# ALL MARKETING SOLUTIONS, INC. not in 2017q3
# ALL MARKETING SOLUTIONS, INC. not in 2017q4
# ALL MARKETING SOLUTIONS, INC. not in 2018q1
# Report that was published in: 2018q2
#         form    fy  fp   fye    period                  adsh  \
# 382   10-Q/A  2016  Q1  1231  20160331  0001494733-18-000009
# 489     10-Q  2017  Q1  1231  20170331  0001494733-18-000011
# 6881    10-Q  2017  Q2  1231  20170630  0001494733-18-000035
#
#                    accepted
# 382   2018-04-04 14:22:00.0
# 489   2018-04-09 13:34:00.0
# 6881  2018-06-07 14:50:00.0
# Fetching Report that was published in :  20170331
# Equity Market Stats for 1Y since Filing on: 2018-04-09 13:34:00
# const                 0.029475
# Risk-Free Return     48.819647
# Risk_Premium_Beta     3.965284
# dtype: float64
# With T-Values:
# const                0.553766
# Risk-Free Return     1.144638
# Risk_Premium_Beta    0.995137
# dtype: float64
# Information Ratio last year: 0.15970237249022648
# 1Y Historic Equity Market Stats (filing between): 2017-04-10 13:34:00 and 2018-04-09 13:34:00
# const                 0.074818
# Risk-Free Return     18.957424
# Risk_Premium_Beta    -4.435402
# dtype: float64
# With T-Values:
# const                1.488239
# Risk-Free Return     0.295233
# Risk_Premium_Beta   -1.369298
# dtype: float64
# Information Ratio next year:0.5441779285247299
# ################################################## Next Period#################################################
# Report that was published in: 2018q3
#         form    fy  fp   fye    period                  adsh  \
# 40    10-Q/A  2017  Q3  1231  20170930  0001494733-18-000050
# 6103  10-K/A  2016  FY  1231  20161231  0001494733-18-000070
# 6359    10-K  2017  FY  1231  20171231  0001494733-18-000077
#
#                    accepted
# 40    2018-07-03 14:44:00.0
# 6103  2018-09-13 14:55:00.0
# 6359  2018-09-25 16:15:00.0
# No 10-Q in 2018q3, fetching 10-K instead
# Fetching Report that was published in :  20171231
# Equity Market Stats for 1Y since Filing on: 2018-09-25 16:15:00
# const                 0.074818
# Risk-Free Return     18.957424
# Risk_Premium_Beta    -4.435402
# dtype: float64
# With T-Values:
# const                1.488239
# Risk-Free Return     0.295233
# Risk_Premium_Beta   -1.369298
# dtype: float64
# Information Ratio last year: 0.5441779285247299
# 1Y Historic Equity Market Stats (filing between): 2017-09-26 16:15:00 and 2018-09-25 16:15:00
# const                  0.084934
# Risk-Free Return    -108.092274
# Risk_Premium_Beta     -6.743401
# dtype: float64
# With T-Values:
# const                1.538669
# Risk-Free Return    -1.372169
# Risk_Premium_Beta   -1.934218
# dtype: float64
# Information Ratio next year:0.6026190639655822
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2018q4
#       form    fy  fp   fye    period                  adsh  \
# 76    10-Q  2018  Q1  1231  20180331  0001548123-18-000258
# 112   10-Q  2018  Q2  1231  20180630  0001548123-18-000264
# 5484  10-Q  2018  Q3  1231  20180930  0001548123-18-000311
#
#                    accepted
# 76    2018-10-05 13:22:00.0
# 112   2018-10-09 14:24:00.0
# 5484  2018-11-19 13:03:00.0
# Fetching Report that was published in :  20180331
# Equity Market Stats for 1Y since Filing on: 2018-10-05 13:22:00
# const                  0.084934
# Risk-Free Return    -108.092274
# Risk_Premium_Beta     -6.743401
# dtype: float64
# With T-Values:
# const                1.538669
# Risk-Free Return    -1.372169
# Risk_Premium_Beta   -1.934218
# dtype: float64
# Information Ratio last year: 0.6026190639655822
# 1Y Historic Equity Market Stats (filing between): 2017-10-06 13:22:00 and 2018-10-05 13:22:00
# const                 0.079261
# Risk-Free Return    -99.159321
# Risk_Premium_Beta    -6.265001
# dtype: float64
# With T-Values:
# const                1.442600
# Risk-Free Return    -1.287085
# Risk_Premium_Beta   -1.823456
# dtype: float64
# Information Ratio next year:0.5415963345255237
# ################################################## Next Period#################################################
# ALL MARKETING SOLUTIONS, INC. not in 2019q1
# ALL MARKETING SOLUTIONS, INC. not in 2019q2
# ALL MARKETING SOLUTIONS, INC. not in 2019q3
# ALL MARKETING SOLUTIONS, INC. not in 2019q4
# ALL MARKETING SOLUTIONS, INC. not in 2020q1
# ALL MARKETING SOLUTIONS, INC. not in 2020q2
# ALL MARKETING SOLUTIONS, INC. not in 2020q3
# ALL MARKETING SOLUTIONS, INC. not in 2020q4
# ALL MARKETING SOLUTIONS, INC. not in 2021q1
# Processing Time in Minutes: 0.032552083333333336
# ALL MARKETING SOLUTIONS, INC. Done
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# Starting with: UNITED STATES BASKETBALL LEAGUE INC
# UNITED STATES BASKETBALL LEAGUE INC not in 2009q1
# UNITED STATES BASKETBALL LEAGUE INC not in 2009q2
# UNITED STATES BASKETBALL LEAGUE INC not in 2009q3
# UNITED STATES BASKETBALL LEAGUE INC not in 2009q4
# UNITED STATES BASKETBALL LEAGUE INC not in 2010q1
# UNITED STATES BASKETBALL LEAGUE INC not in 2010q2
# UNITED STATES BASKETBALL LEAGUE INC not in 2010q3
# UNITED STATES BASKETBALL LEAGUE INC not in 2010q4
# UNITED STATES BASKETBALL LEAGUE INC not in 2011q1
# UNITED STATES BASKETBALL LEAGUE INC not in 2011q2
# UNITED STATES BASKETBALL LEAGUE INC not in 2011q3
# Report that was published in: 2011q4
#      form    fy  fp   fye    period                  adsh  \
# 249  10-Q  2011  Q2  0228  20110831  0001144204-11-058023
#
#                   accepted
# 249  2011-10-17 11:04:00.0
# Fetching Report that was published in :  20110831
# ################################################## Next Period#################################################
# Report that was published in: 2012q1
#       form    fy  fp   fye    period                  adsh  \
# 7071  10-Q  2011  Q3  0228  20111130  0001144204-12-002508
#
#                    accepted
# 7071  2012-01-17 11:23:00.0
# Fetching Report that was published in :  20111130
# ################################################## Next Period#################################################
# Report that was published in: 2012q2
#       form    fy  fp   fye    period                  adsh  \
# 8586  10-K  2011  FY  0229  20120229  0001144204-12-034306
#
#                    accepted
# 8586  2012-06-11 19:15:00.0
# No 10-Q in 2012q2, fetching 10-K instead
# Fetching Report that was published in :  20120229
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2012q3
#      form    fy  fp   fye    period                  adsh  \
# 224  10-Q  2012  Q1  0229  20120531  0001144204-12-039288
#
#                   accepted
# 224  2012-07-13 10:22:00.0
# Fetching Report that was published in :  20120531
# ################################################## Next Period#################################################
# Report that was published in: 2012q4
#         form    fy  fp   fye    period                  adsh  \
# 2698  10-Q/A  2012  Q2  0229  20120831  0001144204-12-059876
#
#                    accepted
# 2698  2012-11-07 09:10:00.0
# No 10-Q in 2012q4, fetching 10-K instead
# No 10-Q or 10-K for 2012q4 skipping to next quarter
# Report that was published in: 2013q1
#      form    fy  fp   fye    period                  adsh  \
# 490  10-Q  2012  Q3  0229  20121130  0001144204-13-003388
#
#                   accepted
# 490  2013-01-22 14:58:00.0
# Fetching Report that was published in :  20121130
# ################################################## Next Period#################################################
# Report that was published in: 2013q2
#       form    fy  fp   fye    period                  adsh  \
# 8775  10-K  2012  FY  0228  20130228  0001144204-13-035419
#
#                    accepted
# 8775  2013-06-18 14:33:00.0
# No 10-Q in 2013q2, fetching 10-K instead
# Fetching Report that was published in :  20130228
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2013q3
#      form    fy  fp   fye    period                  adsh  \
# 570  10-Q  2013  Q1  0228  20130531  0001144204-13-040407
#
#                   accepted
# 570  2013-07-22 12:55:00.0
# Fetching Report that was published in :  20130531
# ################################################## Next Period#################################################
# Report that was published in: 2013q4
#      form    fy  fp   fye    period                  adsh  \
# 280  10-Q  2013  Q2  0228  20130831  0001144204-13-055224
#
#                   accepted
# 280  2013-10-15 16:10:00.0
# Fetching Report that was published in :  20130831
# ################################################## Next Period#################################################
# Report that was published in: 2014q1
#      form    fy  fp   fye    period                  adsh  \
# 469  10-Q  2013  Q3  0228  20131130  0001144204-14-002910
#
#                   accepted
# 469  2014-01-21 06:07:00.0
# Fetching Report that was published in :  20131130
# ################################################## Next Period#################################################
# Report that was published in: 2014q2
#       form    fy  fp   fye    period                  adsh  \
# 8080  10-K  2013  FY  0228  20140228  0001144204-14-037638
#
#                    accepted
# 8080  2014-06-13 16:53:00.0
# No 10-Q in 2014q2, fetching 10-K instead
# Fetching Report that was published in :  20140228
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2014q3
#      form    fy  fp   fye    period                  adsh  \
# 468  10-Q  2014  Q1  0228  20140531  0001144204-14-043828
#
#                   accepted
# 468  2014-07-21 10:54:00.0
# Fetching Report that was published in :  20140531
# ################################################## Next Period#################################################
# Report that was published in: 2014q4
#      form    fy  fp   fye    period                  adsh  \
# 310  10-Q  2014  Q2  0228  20140831  0001144204-14-061311
#
#                   accepted
# 310  2014-10-15 16:20:00.0
# Fetching Report that was published in :  20140831
# ################################################## Next Period#################################################
# Report that was published in: 2015q1
#      form    fy  fp   fye    period                  adsh  \
# 269  10-Q  2014  Q3  0228  20141130  0001144204-15-002214
#
#                   accepted
# 269  2015-01-14 15:41:00.0
# Fetching Report that was published in :  20141130
# ...
# ################################################## Next Period#################################################
# Report that was published in: 2020q2
#        form    fy  fp   fye    period                  adsh  \
# 2924   10-Q  2019  Q3  0831  20190531  0001640334-20-000909
# 15977  10-K  2019  FY  0831  20190831  0001640334-20-001604
#
#                     accepted
# 2924   2020-04-24 11:51:00.0
# 15977  2020-06-26 14:36:00.0
# Fetching Report that was published in :  20190531
# Equity Market Stats for 1Y since Filing on: 2020-04-24 11:51:00
# const                 0.136439
# Risk-Free Return    -29.911225
# Risk_Premium_Beta     3.878975
# dtype: float64
# With T-Values:
# const                1.136042
# Risk-Free Return    -0.194337
# Risk_Premium_Beta    0.461429
# dtype: float64
# Information Ratio last year: 0.6697904256016847
# ################################################## Next Period#################################################
# Report that was published in: 2020q3
#        form    fy  fp   fye    period                  adsh  \
# 891    10-Q  2020  Q1  0831  20191130  0001640334-20-001740
# 2978   10-Q  2020  Q2  0831  20200229  0001640334-20-001881
# 11314  10-Q  2020  Q3  0831  20200531  0001640334-20-002254
#
#                     accepted
# 891    2020-07-13 12:31:00.0
# 2978   2020-07-29 14:35:00.0
# 11314  2020-08-26 12:29:00.0
# Fetching Report that was published in :  20191130
# Equity Market Stats for 1Y since Filing on: 2020-07-13 12:31:00
# const                 0.136439
# Risk-Free Return    -29.911225
# Risk_Premium_Beta     3.878975
# dtype: float64
# With T-Values:
# const                1.136042
# Risk-Free Return    -0.194337
# Risk_Premium_Beta    0.461429
# dtype: float64
# Information Ratio last year: 0.6697904256016847
# ################################################## Next Period#################################################
# Report that was published in: 2020q4
#        form    fy  fp   fye    period                  adsh  \
# 13626  10-K  2020  FY  0831  20200831  0001640334-20-003018
#
#                     accepted
# 13626  2020-12-07 15:35:00.0
# No 10-Q in 2020q4, fetching 10-K instead
# Fetching Report that was published in :  20200831
# Equity Market Stats for 1Y since Filing on: 2020-12-07 15:35:00
# const                 0.136439
# Risk-Free Return    -29.911225
# Risk_Premium_Beta     3.878975
# dtype: float64
# With T-Values:
# const                1.136042
# Risk-Free Return    -0.194337
# Risk_Premium_Beta    0.461429
# dtype: float64
# Information Ratio last year: 0.6697904256016847
# Also saving this as 10-K report
# ################################################## Next Period#################################################
# Report that was published in: 2021q1
#       form    fy  fp   fye    period                  adsh  \
# 8006  10-Q  2021  Q1  0831  20201130  0001640334-21-000422
#
#                    accepted
# 8006  2021-02-23 12:36:00.0
# Fetching Report that was published in :  20201130
# Equity Market Stats for 1Y since Filing on: 2021-02-23 12:36:00
# const                 0.136439
# Risk-Free Return    -29.911225
# Risk_Premium_Beta     3.878975
# dtype: float64
# With T-Values:
# const                1.136042
# Risk-Free Return    -0.194337
# Risk_Premium_Beta    0.461429
# dtype: float64
# Information Ratio last year: 0.6697904256016847
# 1Y Historic Equity Market Stats (filing between): 2020-02-25 12:36:00 and 2021-02-23 12:36:00
# const                  0.080591
# Risk-Free Return     114.439967
# Risk_Premium_Beta      0.561972
# dtype: float64
# With T-Values:
# const                0.830943
# Risk-Free Return     0.391039
# Risk_Premium_Beta    0.204547
# dtype: float64
# Information Ratio next year:0.3998507949274572
# ################################################## Next Period#################################################
# Processing Time in Minutes: 0.034895833333333334
# AMERICAN PARAMOUNT GOLD CORP. Done
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# Starting with: VALE S.A.
# VALE S.A. not in 2009q1
# VALE S.A. not in 2009q2
# VALE S.A. not in 2009q3
# VALE S.A. not in 2009q4
# VALE S.A. not in 2010q1
# Report that was published in: 2010q2
#        form    fy  fp   fye    period                  adsh  \
# 102    20-F  2009  FY  1231  20091231  0000950123-10-040662
# 308   6-K/A  2010  Q1  1231  20100331  0000950123-10-045801
# 497   6-K/A  2010  Q1  1231  20100331  0000950123-10-058134
# 498  20-F/A  2009  FY  1231  20091231  0000950123-10-058317
#
#                   accepted
# 102  2010-04-29 16:43:00.0
# 308  2010-05-06 19:55:00.0
# 497  2010-06-15 09:59:00.0
# 498  2010-06-15 16:47:00.0
# No 10-Q in 2010q2, fetching 10-K instead
# No 10-Q or 10-K for 2010q2 skipping to next quarter
# Report that was published in: 2010q3
#        form    fy  fp   fye    period                  adsh  \
# 312     6-K  2010  Q2  1231  20100630  0000950123-10-070874
# 1341  6-K/A  2010  Q2  1231  20100630  0000950123-10-084383
#
#                    accepted
# 312   2010-08-02 09:10:00.0
# 1341  2010-09-08 08:51:00.0
# No 10-Q in 2010q3, fetching 10-K instead
# No 10-Q or 10-K for 2010q3 skipping to next quarter
# Report that was published in: 2010q4
#     form    fy  fp   fye    period                  adsh  \
# 187  6-K  2010  Q3  1231  20100930  0000950123-10-097146
#
#                   accepted
# 187  2010-10-28 10:14:00.0
# No 10-Q in 2010q4, fetching 10-K instead
# No 10-Q or 10-K for 2010q4 skipping to next quarter
# Report that was published in: 2011q1
#     form    fy  fp   fye    period                  adsh  \
# 588  6-K  2010  FY  1231  20101231  0000950123-11-018212
#
#                   accepted
# 588  2011-02-25 06:10:00.0
# No 10-Q in 2011q1, fetching 10-K instead
# No 10-Q or 10-K for 2011q1 skipping to next quarter
# Report that was published in: 2011q2
#       form    fy  fp   fye    period                  adsh  \
# 226   20-F  2010  FY  1231  20101231  0001047469-11-004222
# 1566   6-K  2011  Q1  1231  20110331  0000950123-11-055825
#
#                    accepted
# 226   2011-04-28 17:13:00.0
# 1566  2011-06-01 17:33:00.0
# No 10-Q in 2011q2, fetching 10-K instead
# No 10-Q or 10-K for 2011q2 skipping to next quarter
# Report that was published in: 2011q3
#      form    fy  fp   fye    period                  adsh  \
# 5736  6-K  2011  Q2  1231  20110630  0001104659-11-049242
#
#                    accepted
# 5736  2011-08-29 17:02:00.0
# No 10-Q in 2011q3, fetching 10-K instead
# No 10-Q or 10-K for 2011q3 skipping to next quarter
# Report that was published in: 2011q4
#      form    fy  fp   fye    period                  adsh  \
# 3974  6-K  2011  Q3  1231  20110930  0001104659-11-063251
#
#                    accepted
# 3974  2011-11-10 17:06:00.0
# No 10-Q in 2011q4, fetching 10-K instead
# No 10-Q or 10-K for 2011q4 skipping to next quarter
# Report that was published in: 2012q1
#      form    fy  fp   fye    period                  adsh  \
# 3667  6-K  2011  Q4  1231  20111231  0001104659-12-014686
#
#                    accepted
# 3667  2012-02-29 18:04:00.0
# No 10-Q in 2012q1, fetching 10-K instead
# No 10-Q or 10-K for 2012q1 skipping to next quarter
# Report that was published in: 2012q2
#       form    fy  fp   fye    period                  adsh  \
# 1012  20-F  2011  FY  1231  20111231  0001047469-12-004389
# 8064   6-K  2012  Q1  1231  20120331  0001104659-12-039878
#
#                    accepted
# 1012  2012-04-17 17:30:00.0
# 8064  2012-05-24 18:02:00.0
# No 10-Q in 2012q2, fetching 10-K instead
# No 10-Q or 10-K for 2012q2 skipping to next quarter
# Report that was published in: 2012q3
#      form    fy  fp   fye    period                  adsh  \
# 2861  6-K  2012  Q2  1231  20120630  0001104659-12-055978
#
#                    accepted
# 2861  2012-08-08 17:01:00.0
# No 10-Q in 2012q3, fetching 10-K instead
# No 10-Q or 10-K for 2012q3 skipping to next quarter
# Report that was published in: 2012q4
#      form    fy  fp   fye    period                  adsh  \
# 2264  6-K  2012  Q3  1231  20120930  0001104659-12-074308
#
#                    accepted
# 2264  2012-11-05 18:05:00.0
# No 10-Q in 2012q4, fetching 10-K instead
# No 10-Q or 10-K for 2012q4 skipping to next quarter
# VALE S.A. not in 2013q1
# Report that was published in: 2013q2
#      form    fy  fp   fye    period                  adsh  \
# 468  20-F  2012  FY  1231  20121231  0001047469-13-003771
#
#                   accepted
# 468  2013-04-02 08:40:00.0
# No 10-Q in 2013q2, fetching 10-K instead
# No 10-Q or 10-K for 2013q2 skipping to next quarter
# VALE S.A. not in 2013q3
# VALE S.A. not in 2013q4
# VALE S.A. not in 2014q1
# VALE S.A. not in 2014q2
# VALE S.A. not in 2014q3
# VALE S.A. not in 2014q4
# VALE S.A. not in 2015q1
# VALE S.A. not in 2015q2
# VALE S.A. not in 2015q3
# VALE S.A. not in 2015q4
# VALE S.A. not in 2016q1
# VALE S.A. not in 2016q2
# VALE S.A. not in 2016q3
# VALE S.A. not in 2016q4
# VALE S.A. not in 2017q1
# VALE S.A. not in 2017q2
# VALE S.A. not in 2017q3
# VALE S.A. not in 2017q4
# VALE S.A. not in 2018q1
# Report that was published in: 2018q2
#      form    fy  fp   fye    period                  adsh  \
# 595  20-F  2017  FY  1231  20171231  0001047469-18-002777
#
#                   accepted
# 595  2018-04-13 07:04:00.0
# No 10-Q in 2018q2, fetching 10-K instead
# No 10-Q or 10-K for 2018q2 skipping to next quarter
# VALE S.A. not in 2018q3
# VALE S.A. not in 2018q4
# VALE S.A. not in 2019q1
# Report that was published in: 2019q2
#       form    fy  fp   fye    period                  adsh  \
# 1003  20-F  2018  FY  1231  20181231  0001047469-19-002391
#
#                    accepted
# 1003  2019-04-18 17:28:00.0
# No 10-Q in 2019q2, fetching 10-K instead
# No 10-Q or 10-K for 2019q2 skipping to next quarter
# VALE S.A. not in 2019q3
# VALE S.A. not in 2019q4
# VALE S.A. not in 2020q1
# Report that was published in: 2020q2
#      form    fy  fp   fye    period                  adsh  \
# 391  20-F  2019  FY  1231  20191231  0001047469-20-002065
#
#                   accepted
# 391  2020-04-03 16:24:00.0
# No 10-Q in 2020q2, fetching 10-K instead
# No 10-Q or 10-K for 2020q2 skipping to next quarter
# VALE S.A. not in 2020q3
# Report that was published in: 2020q4
#      form    fy  fp   fye    period                  adsh  \
# 70  6-K/A  2020  Q2  1231  20200630  0001104659-20-111122
#
#                  accepted
# 70  2020-10-01 16:56:00.0
# No 10-Q in 2020q4, fetching 10-K instead
# No 10-Q or 10-K for 2020q4 skipping to next quarter
# Report that was published in: 2021q1
#        form    fy  fp   fye    period                  adsh  \
# 15402  20-F  2020  FY  1231  20201231  0001047469-21-000687
#
#                     accepted
# 15402  2021-03-23 20:36:00.0
# No 10-Q in 2021q1, fetching 10-K instead
# No 10-Q or 10-K for 2021q1 skipping to next quarter
# Processing Time in Minutes: 0.0015625
# VALE S.A. Done
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# Starting with: ODENZA CORP.
# ODENZA CORP. not in 2009q1
# ODENZA CORP. not in 2009q2
# ODENZA CORP. not in 2009q3
# ODENZA CORP. not in 2009q4
# ODENZA CORP. not in 2010q1
# ODENZA CORP. not in 2010q2
# ODENZA CORP. not in 2010q3
# ODENZA CORP. not in 2010q4
# ODENZA CORP. not in 2011q1
# ODENZA CORP. not in 2011q2
# ODENZA CORP. not in 2011q3
# Report that was published in: 2011q4
#         form    fy  fp   fye    period                  adsh  \
# 4     10-Q/A  2011  Q2  0131  20110731  0001477932-11-002068
# 7560    10-Q  2011  Q3  0131  20111031  0001477932-11-002780
#
#                    accepted
# 4     2011-10-03 16:50:00.0
# 7560  2011-12-14 10:59:00.0
# Fetching Report that was published in :  20111031
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\av\__init__.py in _read_lines(self, out)
#      71         try:
# ---> 72             df = pd.DataFrame.from_dict(out[self.data_key], orient="index")
#      73         except KeyError:
#
# KeyError: 'Weekly Adjusted Time Series'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-7846e2e19134> in <module>
#      86                 try:
# ---> 87                     share_price_ts = pdr.DataReader(str(firms_df[firms_df["CIK"]==CIK]["Ticker"].iloc[0]), "av-weekly-adjusted", start=start,end=end)["adjusted close"]
#      88                 except ValueError:
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     609     elif data_source == "av-weekly-adjusted":
# --> 610         return AVTimeSeriesReader(
#     611             symbols=name,
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py in read(self)
#      99         try:
# --> 100             return self._read_one_data(self.url, self.params)
#     101         finally:
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py in _read_one_data(self, url, params)
#     111             raise NotImplementedError(self._format)
# --> 112         return self._read_lines(out)
#     113
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\av\time_series.py in _read_lines(self, out)
#     113     def _read_lines(self, out):
# --> 114         data = super(AVTimeSeriesReader, self)._read_lines(out)
#     115         # reverse since alphavantage returns descending by date
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\av\__init__.py in _read_lines(self, out)
#      74             if "Error Message" in out:
# ---> 75                 raise ValueError(
#      76                     "The requested symbol {} could not be "
#
# ValueError: The requested symbol odza could not be retrieved. Check valid ticker.
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-7846e2e19134> in <module>
#      88                 except ValueError:
#      89                     try:
# ---> 90                         share_price_ts = pdr.DataReader(str(firms_df[firms_df["CIK"]==CIK]["Ticker"].iloc[1]), "av-weekly-adjusted", start=start,end=end)["adjusted close"]
#      91                     except ValueError:
#      92                         print('No Stock Prices available')
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# # Some ideas for supervised learning techniques to predict outperformance

# %% [markdown]
# Idea:
# * For each year we have a number of features (last years B/S and I/S, and various statistical features of stock prices)
# * For each year we also have a number of targets (next years performance metrics)
# * Let an algorythm train on e.g. 5 years of data for 100 companies to use all accounting data and predict next years performance metrics
